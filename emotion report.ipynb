# %%
import re
import requests
import jieba
from snownlp import SnowNLP
import pandas as pd
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
url = 'https://api.bilibili.com/x/v1/dm/list.so?oid=833286904'
headers = {
    'cookie': 'buvid3=C01AC0E7-39F3-4B6B-A3D3-3694B4B9DE3F18568infoc; rpdid=|(u~)YYu|m))0J\'uYuuJ|RkYR; blackside_state=0; _uuid=DDC5D475-7FEC-10D5C-F65C-7F108845D9110128540infoc; buvid4=F33B6F33-E729-11A1-361D-0771A6D0F9A530044-022012522-Ed+iBJe/LoAbuLszV4Kbnw%3D%3D; fingerprint3=94c78d98d4109b56446062e8808c1dba; i-wanna-go-back=-1; buvid_fp_plain=undefined; LIVE_BUVID=AUTO1016437080560804; nostalgia_conf=-1; CURRENT_BLACKGAP=0; hit-dyn-v2=1; is-2022-channel=1; fingerprint=75bbe94c3ceebf271b09fbde540f90f3; buvid_fp=75bbe94c3ceebf271b09fbde540f90f3; DedeUserID=641706985; DedeUserID__ckMd5=dd42c5ea734fa0d5; b_ut=5; CURRENT_QUALITY=80; b_nut=100; SESSDATA=cf642170%2C1680496658%2C1ec66%2Aa1; bili_jct=64c027458903950649f8886ed91f8627; sid=5aabkigx; innersign=1; PVID=5; bp_video_offset_641706985=713538997424488400; CURRENT_FNVAL=4048; b_lsid=91EA95E7_183A8306750',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36'
}

# %%
#response = requests.get(url=url,headers=headers)

# %%
response = requests.get(url=url,headers=headers)
response.encoding = 'utf-8'
#print(response.text)
content_list = re.findall('<d p=".*?">(.*?)</d>',response.text)
#print(content_list)
for index in content_list:
    print(index)
    with open ('A:/shixi/danmuiphone.txt',mode = 'a',encoding = 'utf-8') as f:
        f.write(index)
        f.write('\n')
# Out:
# ['负提升哈哈哈哈哈哈哈', '红魔是游戏手机啊大哥们，不是一条赛道的', '为啥麒麟9000没用散热背夹跑', '夭寿啦，苹果做散热啦！！！', '导游就是在屏幕和主板之间多了块铁板', '下次一定', '说13香的人呢？哈哈哈哈', '下次一定', '《寄PU》', '再不改后面可能会有的更大功率的芯片没法用了', '下次一定', '天玑8000：没想到吧，还是我', '众所周知，原神是一个测试手机性能的软件。', '库克：涨停了', '另一方面就是iPhone14系列是新机', '下次一定', '乔布斯：库克，你在搞什么飞机', '三连等后续', '《散热背夹测试》：发热还是高', '就这，哈哈哈，安卓', '我的小米11烧了wifi', '指加了块铝板', '看来A13在机身45度时就只能30几帧了', 'pc3060显卡玩家表示不服（我全程60帧显卡才百分之50的占用哎！！！！！！）', '8+ yyds 手持12su', '14最香', '左下显示：用散热背夹测试', '《外  星  科  技》', '库克：修复了省电模式和普通模式放反了的bug（', '是旗舰机的标杆，安卓现在都有6000毫安大电池的手机了', '我超，OP！', 'k50能耗太强了', '主要友商每一个能打的', '哈哈哈外星科技', '《外 星 科 技》', '我初三的时候用的机器 iphone5C 当时iphone6都还没出', '今年的14很像一个半成品，感觉在为15铺路', '14PLUS延迟到10月发售一定有杀手锏', '盲猜用了一块铜板，淘宝5块钱', '14plus有可能成为最强游戏手机，续航和重量散热等，都是最强', '30°重庆夏天室温都40', '13夏天玩原神打开就不出3分钟就ppt', '《均匀》', '《46.4》', '《888复活》', '《散热升级》', '目前芯片看来进步很难很慢了', '我的pc开4k不卡', '《升级了散热》', '《寄PU》', 'k50U是120w充电，哪怕是10w跑，接上充电器放五分钟休息下眼镜，充好了继续跑', '帧数稳定好多', '正在摸鱼', '卧龙凤雏', '加个散热背夹 效果岂不是更好', '《旧瓶装旧酒》', '《一见如故》', '安卓画质调高了', '真的很亮', '我用的就是天机8100', '过分哈哈哈', '《十 三 香》', '《喜爱有加》', '安兔兔相当于鲁大师吧', '跑个原神哈哈哈', '官方超频版', '下次一定', '好的，我买14plus', '13pro太香了', '坏了，买个实验手机', '麒麟砍爆火龙', '王守义永远的神', '13pm嬉笑了   完全不用换了', '明年15可以测枫丹了', '修复了省电模式是游戏模式的bug', '我的12是撑不到枫丹了', '刚从大米那过来，不如12su，甚至主摄是差距最小的', '惊喜吗哈哈哈', '安卓日常成片也是1200w啊', '幸好是要求时间以后', '正在摸鱼', '看来还是我的13pm更香', '厨子！！！', '下次一定', '《有限》', '我pro居然最短，不过我平常也一直要带个背夹电池的，一样的', '是均热板，已经有人拆过了，屏幕下和玻璃背板后都有一块金属板', '还好我不玩元神（狗头', '挖孔屏', '屏都快剁碎了哈哈哈', '强行打兵，哈哈哈', '《站起来》', '14香了哈哈哈哈哈', '←夏天插卡用5G流量跑原神，怕是要直接送走手机了', '《小升级》', '挤的一手好牙膏', '《寄PU》', '就一块vc 均热板', '就是中框连着多了块金属板子，把屏幕和主板电池隔开了', '没感觉到有卡顿现象，可能我用的是PC', '我超 O！', '好家伙，期待iPhone15上M3芯片', '14和14plus的60hz主要是省电', '高情商：《优化》低情商：挤牙膏', '每秒1HZ刷新率，烧不了的', '天啊', 'a1！5！', 'A系列：开摆', '跑分刺客：原神', '本来买了手机准备玩原神 现在想想算了', '？？哈哈哈哈哈哈哈哈', '主要是今年天气 太热了！！！', '主要是今年天气 太热了！！！', '主要是今年天气 太热了！！！', 'SE才是真的好用', '《寄PU》', '懂了，低端电脑芯片在手机上实验', '单层主板石锤！！', '有没有可能，以后M系列也可以用在手机上(x', '用了一块铝板', '可能是未来最大的一次', '《烧屏神器》', '相比4G+A16，我其实更喜欢6G+A15', '意思就是以后就不更新a系列了（', '带个壳子哈哈哈', '《在散热背夹下》', '可是快要冬天了诶', '《原神》', 'k50为啥有一段降到10以下了……', '超级期待14plus', '红米那个真牛哈哈哈', '《游戏模式》', '前几天买了个13，我发现现在能管它叫iPhone14了', '下次一定', '1天!', '42+85+', '好家伙，不愧是电脑游戏', '14依然没有高刷，这个就是最大短板', '远峰蓝下放', '好明显啊', '好家伙powermonitor', '《喜爱有加》', '版本更新负优化', '月销0哈哈哈', '改进散热今年才想起来就离谱', '散热更好功耗更大', '每个视频仅消耗5个测试员', 'a14 正面拆机是个铁板，北念拆机才能看见电池主板。正面整块和机身一体的铁板就是散热的', '蓝厂牌面，挤牙膏', '好家伙，经典五颜六色', '8+以可啊', '骁龙8：这个我熟', '库克（库存克星）', '下次一定', '来惹来惹~', '抽奖', 'Intel：勿cue', '下次一定', '大量实验数据的感觉', '知名跑分测试软件——原神', '14::诶，我跳出来了，我又跳回去，怎么样怎么样你打我呀', '《均使用散热背夹进行散热》', '14加了中框', 'se3居然还是卡，apple真狠', '对于不玩原神的我，够用', 'ps5原神3.0须弥探索完全不卡的路过', '但是我用手机下原神就只是为了换个树脂啊', '高通这我熟啊哈哈哈', '也有可能是用了新的屏幕发光材质带来的', '13pro沉默了', '13pro才是真的香', '牙膏都挤在摄像头和熄屏显示上了，所以在作A16的时候牙膏已经没多少了', '高通：：勿cue', '崩坏3就是太吃gpu导致卡', '果表用户表示很熟悉', '13pro狂喜', '好了，我的米10可以再用一年', '《可以期待14plus了》', '《旧瓶装旧酒》', '按时超过10w', '小米直接干到个位数了  哈哈哈哈哈哈哈', '每年换新计划的路过，爽完这一年明年用新款', '就是加了块铝板', 's21卡槽也在左下啊', '《预设-高》', 'mini6表示须弥压力太大了', '夏天测才行', '厨子：我们优化了一下省电模式', '《旧瓶装旧酒》', '哎呀，幸好我不玩原神啊', '果14最强游戏机（）', '想起上次测的红魔那个手机60hz一条直线干满半小时', '帧率高了功耗高不是很正常', '5分钟《更强》', '我还以为是跌落测试（被打', '《寄PU》', '钟文泽评测开息屏时锁屏耗电翻倍', '前三台完全一样(doge)', '麒麟9000还能跑满40帧吗(doge)', '之前没有散热现在加了散热=重做了散热', '本来想买13 Pro max.现在我却有点期待14 Plus。', '好家伙，5apu的飞友现身了', '看到14后，王守义意味深长的说：还是十三香', '可以期待年底的高通试试', '《酷睿13：就是我哒！～》', '《酷睿13：就是我哒！～》', '中画质我k50都稳60', '预示着安卓的锐龙要出现了！', '不服泡个愿神', '原神：我是手机测试软件', '《游戏模式》', '588', '首发亲测 依旧热', '《旧瓶装旧酒》', '笑死，在璃月60满，须弥城跑图就能到30以下', 'A系列在手机界已经无敌了 发展M系列芯片很合理', '下次就要上太空了', '《这个超大鼠标垫特好用》', '这一件三连以为视频快结束了，我准备关闭了....', '原神：我还没开120kz呢', '测个小游戏（确信）', '其实是芯片不太行，所以显得散热了', '明明是实验室数据（doge', '已经看到未来了，到时候苹果疯狂挤牙膏，而且麒麟芯片会一直突破极限。', '13没高像素，没灵动岛，没2000尼特屏幕', '《只是》', '看了一个拆机视频，14屏幕和芯片电池电路板之类是分开的', '14plus应该表现是最好的吧', '电脑在须弥城里都掉帧', '还没测呢就要三连，真是过分（doge', '哈哈哈还是13香', '《略微》《稍微》', '隔壁拆了，CPU可以直接接触背面了，做了散热', '《月销0》', '所以13真的香', '现在苹果开始最安卓了吗哈哈哈', '感觉14plus烧14系列最香的了', '4k人在摸鱼', '看了 就当自己曾经拥有过了', '我的5c还在家里睡觉', '极限测试', '优化太差，哈哈', '真是13香啊', '可是我有3080哎谁用手机玩啊', 'ps5卡了', '选择13加背甲', '13pm用户表示很开心！', '与中框一体的金属隔板', '火龙果哈哈哈', '乔布斯：我一直盯着你们', '中框用回了14年前的iPhone 4所以散热提升了', '扎心~', '这里右边看起来好像iPhone4啊，哈哈哈哈', 'A系列实 ...
# 负提升哈哈哈哈哈哈哈
# 红魔是游戏手机啊大哥们，不是一条赛道的
# 为啥麒麟9000没用散热背夹跑
# 夭寿啦，苹果做散热啦！！！
# 导游就是在屏幕和主板之间多了块铁板
# 下次一定
# 说13香的人呢？哈哈哈哈
# 下次一定
# 《寄PU》
# 再不改后面可能会有的更大功率的芯片没法用了
# 下次一定
# 天玑8000：没想到吧，还是我
# 众所周知，原神是一个测试手机性能的软件。
# 库克：涨停了
# 另一方面就是iPhone14系列是新机
# 下次一定
# 乔布斯：库克，你在搞什么飞机
# 三连等后续
# 《散热背夹测试》：发热还是高
# 就这，哈哈哈，安卓
# 我的小米11烧了wifi
# 指加了块铝板
# 看来A13在机身45度时就只能30几帧了
# pc3060显卡玩家表示不服（我全程60帧显卡才百分之50的占用哎！！！！！！）
# 8+ yyds 手持12su
# 14最香
# 左下显示：用散热背夹测试
# 《外  星  科  技》
# 库克：修复了省电模式和普通模式放反了的bug（
# 是旗舰机的标杆，安卓现在都有6000毫安大电池的手机了
# 我超，OP！
# k50能耗太强了
# 主要友商每一个能打的
# 哈哈哈外星科技
# 《外 星 科 技》
# 我初三的时候用的机器 iphone5C 当时iphone6都还没出
# 今年的14很像一个半成品，感觉在为15铺路
# 14PLUS延迟到10月发售一定有杀手锏
# 盲猜用了一块铜板，淘宝5块钱
# 14plus有可能成为最强游戏手机，续航和重量散热等，都是最强
# 30°重庆夏天室温都40
# 13夏天玩原神打开就不出3分钟就ppt
# 《均匀》
# 《46.4》
# 《888复活》
# 《散热升级》
# 目前芯片看来进步很难很慢了
# 我的pc开4k不卡
# 《升级了散热》
# 《寄PU》
# k50U是120w充电，哪怕是10w跑，接上充电器放五分钟休息下眼镜，充好了继续跑
# 帧数稳定好多
# 正在摸鱼
# 卧龙凤雏
# 加个散热背夹 效果岂不是更好
# 《旧瓶装旧酒》
# 《一见如故》
# 安卓画质调高了
# 真的很亮
# 我用的就是天机8100
# 过分哈哈哈
# 《十 三 香》
# 《喜爱有加》
# 安兔兔相当于鲁大师吧
# 跑个原神哈哈哈
# 官方超频版
# 下次一定
# 好的，我买14plus
# 13pro太香了
# 坏了，买个实验手机
# 麒麟砍爆火龙
# 王守义永远的神
# 13pm嬉笑了   完全不用换了
# 明年15可以测枫丹了
# 修复了省电模式是游戏模式的bug
# 我的12是撑不到枫丹了
# 刚从大米那过来，不如12su，甚至主摄是差距最小的
# 惊喜吗哈哈哈
# 安卓日常成片也是1200w啊
# 幸好是要求时间以后
# 正在摸鱼
# 看来还是我的13pm更香
# 厨子！！！
# 下次一定
# 《有限》
# 我pro居然最短，不过我平常也一直要带个背夹电池的，一样的
# 是均热板，已经有人拆过了，屏幕下和玻璃背板后都有一块金属板
# 还好我不玩元神（狗头
# 挖孔屏
# 屏都快剁碎了哈哈哈
# 强行打兵，哈哈哈
# 《站起来》
# 14香了哈哈哈哈哈
# ←夏天插卡用5G流量跑原神，怕是要直接送走手机了
# 《小升级》
# 挤的一手好牙膏
# 《寄PU》
# 就一块vc 均热板
# 就是中框连着多了块金属板子，把屏幕和主板电池隔开了
# 没感觉到有卡顿现象，可能我用的是PC
# 我超 O！
# 好家伙，期待iPhone15上M3芯片
# 14和14plus的60hz主要是省电
# 高情商：《优化》低情商：挤牙膏
# 每秒1HZ刷新率，烧不了的
# 天啊
# a1！5！
# A系列：开摆
# 跑分刺客：原神
# 本来买了手机准备玩原神 现在想想算了
# ？？哈哈哈哈哈哈哈哈
# 主要是今年天气 太热了！！！
# 主要是今年天气 太热了！！！
# 主要是今年天气 太热了！！！
# SE才是真的好用
# 《寄PU》
# 懂了，低端电脑芯片在手机上实验
# 单层主板石锤！！
# 有没有可能，以后M系列也可以用在手机上(x
# 用了一块铝板
# 可能是未来最大的一次
# 《烧屏神器》
# 相比4G+A16，我其实更喜欢6G+A15
# 意思就是以后就不更新a系列了（
# 带个壳子哈哈哈
# 《在散热背夹下》
# 可是快要冬天了诶
# 《原神》
# k50为啥有一段降到10以下了……
# 超级期待14plus
# 红米那个真牛哈哈哈
# 《游戏模式》
# 前几天买了个13，我发现现在能管它叫iPhone14了
# 下次一定
# 1天!
# 42+85+
# 好家伙，不愧是电脑游戏
# 14依然没有高刷，这个就是最大短板
# 远峰蓝下放
# 好明显啊
# 好家伙powermonitor
# 《喜爱有加》
# 版本更新负优化
# 月销0哈哈哈
# 改进散热今年才想起来就离谱
# 散热更好功耗更大
# 每个视频仅消耗5个测试员
# a14 正面拆机是个铁板，北念拆机才能看见电池主板。正面整块和机身一体的铁板就是散热的
# 蓝厂牌面，挤牙膏
# 好家伙，经典五颜六色
# 8+以可啊
# 骁龙8：这个我熟
# 库克（库存克星）
# 下次一定
# 来惹来惹~
# 抽奖
# Intel：勿cue
# 下次一定
# 大量实验数据的感觉
# 知名跑分测试软件——原神
# 14::诶，我跳出来了，我又跳回去，怎么样怎么样你打我呀
# 《均使用散热背夹进行散热》
# 14加了中框
# se3居然还是卡，apple真狠
# 对于不玩原神的我，够用
# ps5原神3.0须弥探索完全不卡的路过
# 但是我用手机下原神就只是为了换个树脂啊
# 高通这我熟啊哈哈哈
# 也有可能是用了新的屏幕发光材质带来的
# 13pro沉默了
# 13pro才是真的香
# 牙膏都挤在摄像头和熄屏显示上了，所以在作A16的时候牙膏已经没多少了
# 高通：：勿cue
# 崩坏3就是太吃gpu导致卡
# 果表用户表示很熟悉
# 13pro狂喜
# 好了，我的米10可以再用一年
# 《可以期待14plus了》
# 《旧瓶装旧酒》
# 按时超过10w
# 小米直接干到个位数了  哈哈哈哈哈哈哈
# 每年换新计划的路过，爽完这一年明年用新款
# 就是加了块铝板
# s21卡槽也在左下啊
# 《预设-高》
# mini6表示须弥压力太大了
# 夏天测才行
# 厨子：我们优化了一下省电模式
# 《旧瓶装旧酒》
# 哎呀，幸好我不玩原神啊
# 果14最强游戏机（）
# 想起上次测的红魔那个手机60hz一条直线干满半小时
# 帧率高了功耗高不是很正常
# 5分钟《更强》
# 我还以为是跌落测试（被打
# 《寄PU》
# 钟文泽评测开息屏时锁屏耗电翻倍
# 前三台完全一样(doge)
# 麒麟9000还能跑满40帧吗(doge)
# 之前没有散热现在加了散热=重做了散热
# 本来想买13 Pro max.现在我却有点期待14 Plus。
# 好家伙，5apu的飞友现身了
# 看到14后，王守义意味深长的说：还是十三香
# 可以期待年底的高通试试
# 《酷睿13：就是我哒！～》
# 《酷睿13：就是我哒！～》
# 中画质我k50都稳60
# 预示着安卓的锐龙要出现了！
# 不服泡个愿神
# 原神：我是手机测试软件
# 《游戏模式》
# 588
# 首发亲测 依旧热
# 《旧瓶装旧酒》
# 笑死，在璃月60满，须弥城跑图就能到30以下
# A系列在手机界已经无敌了 发展M系列芯片很合理
# 下次就要上太空了
# 《这个超大鼠标垫特好用》
# 这一件三连以为视频快结束了，我准备关闭了....
# 原神：我还没开120kz呢
# 测个小游戏（确信）
# 其实是芯片不太行，所以显得散热了
# 明明是实验室数据（doge
# 已经看到未来了，到时候苹果疯狂挤牙膏，而且麒麟芯片会一直突破极限。
# 13没高像素，没灵动岛，没2000尼特屏幕
# 《只是》
# 看了一个拆机视频，14屏幕和芯片电池电路板之类是分开的
# 14plus应该表现是最好的吧
# 电脑在须弥城里都掉帧
# 还没测呢就要三连，真是过分（doge
# 哈哈哈还是13香
# 《略微》《稍微》
# 隔壁拆了，CPU可以直接接触背面了，做了散热
# 《月销0》
# 所以13真的香
# 现在苹果开始最安卓了吗哈哈哈
# 感觉14plus烧14系列最香的了
# 4k人在摸鱼
# 看了 就当自己曾经拥有过了
# 我的5c还在家里睡觉
# 极限测试
# 优化太差，哈哈
# 真是13香啊
# 可是我有3080哎谁用手机玩啊
# ps5卡了
# 选择13加背甲
# 13pm用户表示很开心！
# 与中框一体的金属隔板
# 火龙果哈哈哈
# 乔布斯：我一直盯着你们
# 中框用回了14年前的iPhone 4所以散热提升了
# 扎心~
# 这里右边看起来好像iPhone4啊，哈哈哈哈
# A系列实验新架构，等成熟了再用在M系列桌面级
# 14只是做到了13应该做到的
# 13系列或将成为最大赢家
# 看到了三星和台积电的差距
# 十周年纪念青春版
# 《安卓：我充电快，续航没啥所谓》
# 主板是双层设计 中间夹了散热材料吧
# 十甚至九的小电池
# 13是真的香
# 对 现在是秋天了
# 总结：买了13的爱换不换 没13系列的要换就换14系列
# 我也是
# A15真成神U了
# 3.46G快赶上电脑CPU了
# 方向对了 哈哈哈
# 亮屏用的
# 《骁龙888与865》
# 13是真相了
# 所以官方必须下架13pro系列 哈哈
# 《Skylake》
# 《十三香》
# 有人拆了，导热就是屏幕和主板间多了块中框
# 双层主板主要是提高集成度 让机身塞下更大的电池
# 安卓有散热组件
# 一并超哈哈哈哈
# 我在富士康贴的就是石磨贴 没有均热板 只有一小块主板盖板石墨片
# 功耗高加充电快等于电池短命
# 《 游  戏  模  式 》
# 懂了，买三星
# 好家伙，还真是13香了
# 5c我还挺喜欢，第一款入手的iPhone，颜值手感当时都挺不错
# 然后iQOOz6x（doge）
# 全部机型都用了散热背甲啊
# 左边的机型：三星S22
# 人类追上了外星科技！！！
# 《改进散热》
# 因为是外星科技所以可以多用几次
# 卧槽。我5c已经10年了啊
# 现在夏天已经40℃了
# 心电图
# 其实还好，主要是a16提升也不大
# 13真的香
# 标题《散热不错》
# 啊这！
# 不用拆了就是屏幕下边压了一整块钢板
# 幸好我不怎么打游戏
# 《略强》
# 看了拆解，散了和没散一样┐（─__─）┌
# 但还是13pro香，跟14plus一个价格，但是有高刷和更好的质感及摄像头
# 他~ 会魔法吧~
# 天哪，苹果居然会考虑散热
# 有没有一种可能安卓的散热只是夸夸其谈。
# 是遥遥领先（
# 有一说一那个30℃的测试才更接近实际使用吧，13pro一直都是实验室测试各种无敌，一用起来和骁龙五五开，我觉得实际体验14pro会比13pro强不少
# 上红魔啊，用游戏手机欺负它！
# 我的m1不卡
# 有拆机了，是石墨贴
# woc，手点啊
# 确实省电了哈哈哈哈哈
# 一路从哈尔滨跑到昆明
# 懂了13+背夹 &gt; 14  （狗头
# 满血A15+高刷+灵动岛才是YYDS
# 《高画质》《60帧》
# SE3 瞬间变得超级香
# 只能冬天玩原神
# 很强但是有灵动岛吗～
# 官方超频版
# 哈哈哈哈哈哈哈哈哈哈，还是13香
# 期待A17
# 啊啊啊啊啊不换了
# 我的13pm打王者半小时掉帧严重
# 须弥真的太可怕了 植被之类基本塞满地图地上和地下也是拉满的
# 骁龙8+站起来了卧槽
# 开全天候显示，日常使用打不过13pm
# 8+不错哦
# 火龙果了今年
# 我笔记本3070叶兰跑图有时候也会掉帧.....
# 瓶颈真的到了
# 6啊
# 14+
# 14+成了
# 牙膏厂：这我熟
# 测试一下插卡5g跑原神
# 原神手机版光影已经砍了很多了
# 我想问一下，发布会散热了吗
# 顿时感觉手里的13香爆了
# 原因：频率无法固定
# 考虑到价格13 PM最强
# 好家伙 不会是M系列测试生产线的边角料切的吧
# 夜兰：你礼貌吗
# 我骁龙888都能……
# 15更香
# 还好我买的13
# 正式对标小米了属于是
# 边角料，或者是实验新的M芯片铺路的垫脚石
# 高情商：喜爱有加
# 13pm：14pm超过我了是不是要我夸夸你啊
# 买了14pm，但是根本不玩游戏，我居然看了半天
# 全球气温升高，库克手被烫到了
# 《喜爱有加》
# 你应该拿发布会上使用的A13来比（doge
# 我870都稳定9
# 可它有单电芯5000mAh+120W
# 但是安卓有100w充电啊
# 超过iPad
# 看了一样视频发布时间，嗯，是新的
# 游戏模式增强了
# 1.5倍速有惊喜
# 这就更期待明年A17芯片了
# 感觉很强专业
# ipad pro 偶尔卡
# 《完全吊打》
# 突然想到，14【】
# 哈哈哈，和我想的一样
# 上5G 30°C
# 13香是真的香
# 提升挖矿性能（doge
# 所有的软件没有适配新pro，过段时间再测会准一些
# 下次是不是要叫奥林匹斯峰了（位于火星 太阳系最高峰）
# 超了个频（不是）
# 红魔7sp；都闪开，让我来！
# 骁龙888：这我熟！
# 好一个旧瓶装旧酒
# 先别笑 火龙测试新版本会哭
# 可以玩但只有几分钟
# 王守义:听我的没错
# 既然已经有散热了，下一代可不可以上快充（doge）
# 1.1万+人，哈哈
# 《0.3W的性能释放》
# 13PM用户笑死在屏幕前
# 《改个名字》
# 手持13香超大杯。安心了
# 看到这里我觉得真该感谢原神哈哈
# 完了，我成替身了
# 强得很！
# 别盲猜了，发布会就说的plus是整个14系列（包括Pro）续航最强的
# 真不觉的有多强为啥我的13玩个原神都会花屏
# 夏天室内30度都算是凉快温度
# 不会烧屏的，放心！
# 苹果：我能拿A13跟你们比已经看得起你们了（doge）
# 13pro用户集合！
# 《甚至》
# 13又15还16 14的属实给我整晕了
# K3V2同系列（狗头）
# 很正常的场景啊
# 原神：我们征服了手机厂商
# 好耶，13香！
# 我3060一到须弥城就严重掉帧
# 小荷才露尖尖角
# ps5都卡就离谱
# 又名：《真实场景测试》
# 红魔：对对对正是在下
# 《明  显》
# 直接寄！！！！
# 13pm接着用了哈哈哈
# 60hz的游戏机，哈哈哈哈哈哈哈哈
# 超级期待14plus，有可能又成为一代神机
# 13香，哈哈哈哈
# 真的有人用手机打游戏吗doge
# 里边结构改了
# 笑死我了哈哈哈哈哈
# 笑死我了哈哈哈哈哈
# Kaby Lake（7200U）受害者在此
# 我的PS5并没有卡呀
# 安心在还12个月
# 已经没啥创新力了
# 我的13pm真的太香啦
# 天玑好
# 今年直接秒杀安卓
# 买13pro！！！！
# 芯片制程确实已经快到头了
# 没有均热板
# 手机芯片日常使用都性能过剩
# 离屏测试是什么应用场景？机器学习？
# 所以说A15的满血版是真的香
# 12系列我都放心
# 13pm真的YYDS 哈哈哈哈哈哈
# 提升巨大 太棒了
# 下次丕定
# 永远不能想象米忽悠的优化2
# 卧槽，我也是，
# 就在今年！
# 《K50 ULTRU》
# 噗哈哈哈
# a系列：明明是我先来的
# 13在14面前是弟弟
# 米哈游：就你叫苹果啊？你不是很厉害吗（bushi)
# 《0.04》
# 卧槽  5
# 手里的13Pro加个散热背夹，真香
# 一并超！一并超！一并超！
# 所以，热的必须做散热了
# 8+还没天玑9000好hhh
# 低情商：挤牙膏    高情商：喜爱有加
# 可是安卓这边有着动辄几十上百瓦的充电啊（doge）
# 原神，《测试软件》
# 当然要挤牙膏啦！！！不然后面的机型怎么做啊
# 衣服哈哈哈
# 14plus应该更香
# 行！
# 行！
# A16：坏了，我成替身了（bushi）
# 14+是不是单层主板
# S22好漂亮 心动了
# 《月销0》
# 3000块的K50至尊版都能稳定60
# 14plus发布会有提到散热，其它三个机型没有。
# 8+nb
# 8+1已经能稳定59.5了
# 13PM永远的神！！
# 《游戏模式》
# 原神——一款与时俱进的跑分软件
# 16其实就是小超频的15
# 新机不是应该过段时间 优化后再测试么
# 这是什么心电图啊哈哈哈哈哈
# 14+已经锁定年度游戏机头牌
# 哈哈，三星也是今年开始聊散热，不过还是拉（doge）
# 13标准也就一般香，14+2G和散热，作用明显太多了，明显能钉更久
# 13依然香，14还是买那两个大屏幕的！！！
# 刚出不适配  按照惯例 一般在16.3的版本下基本会好了
# 14=13pro+散热了
# 15：我才是16
# 夜天后上线
# 须弥没有一座山是实心的
# 感谢安卓拉跨~~~
# 一回生二回熟
# 挤牙膏是主要原因
# up的应该是测试机
# 懂了，买K50 ultra（doge）
# 13：啊哈
# tick tock(
# 13pro也太香了
# 修复了省电模式实际上是游戏模式的bug
# 烧龙888：这个我熟
# 厕所小王子，摸鱼出击
# 做日常够了（doge）
# 各位玩原神，把散热背甲带上吧。开最高特效很烫
# 可以啊
# 《上手体验》
# 嘶～
# 梦回炎龙8g1
# 土豪啊，居然有夜兰
# 我的9900k+3080ti不卡
# 1070ti 1080p最高配主城卡
# 更期待骁龙的下一代芯片了…哈哈
# 红魔：请把我丢到沸水测试
# 心电图
# 最好的散热还得是单层主板
# 你对13pro更感兴趣（doge
# 等高通一年 泪目
# 《略强》
# 确实跑分软件哈哈哈
# 《库存克星》
# 5APU（错乱）
# 加强了个寂寞
# 哈哈哈，(安兔兔苹果特别版)根据苹果往年GPU性能提升推断，得出新处理器应该有24%提升，所以分数也高了这么多
# 主要是没有提升
# 《月销0》
# 13香！！！！
# 但是安卓便宜+散热更好+充电更快
# 火龙8:这个我熟
# 安卓功耗高但是快充回血也快啊
# 安卓功耗高但是快充回血也快啊
# 众所周知,小核就是用来跑分的
# 哈哈哈哈，a16和a15就只是换了一个名字！？？
# 13香哈哈哈
# 夜兰：我谢谢你
# 高通直呼内行（doge
# (5-4)/5＝20%是吧（
# A16：坏了 我成试验田了
# 我的mini6突然香了
# 到达世界最高峰，下一次就只能往下走了
# 所以14plus晚发售
# 三星用的火龙
# 60hz的6.7寸屏不知道有什么期待的，期待明显卡顿吗
# 月销零。。。。哈哈哈哈哈
# 哈哈哈哈，憋不住了
# 60帧哈哈哈哈
# 第一眼我以为是骁龙8的曲线........
# 手机端甜甜圈!
# 烧屏换新 香呀~
# 《外星科技》
# 已经三连
# 库克：明年你还能提前拿到手机蒜我输
# Pro（破）
# 13pro用户表示上班就猜到14不会有大更新，四月份果断入了
# woc可以可以
# 好家伙，反向升级
# 米哈游（负）优化之王。
# 库克：牙膏要慢慢挤。good morning
# 超频版本
# 用更小的电池跑出最长的时间！！！
# 辛苦，两连了
# 《正片开始》
# 《芯片本身的优化》
# 《世界名画》
# (5-4)/5＝0.2
# 《有所提升》
# intel：勿cue
# 《月销0》
# 苹果：我本身就是电脑公司，手机是对我最大的误会
# 但是安卓充电快啊
# 心电图
# 库克：你把测试机还给我
# 卧槽真的13香啊
# 安卓功耗大但是充电快啊
# 乔布斯：？
# 《2.3w》
# 高通:唉，学我！
# Android已经躺了
# 到达世界最高峰（
# 10000元的实验手机（doge）
# 强烈建议测试对比mini6和14plus！！
# 给你们十个硬币！！！可惜给不了
# 均使用散热背架。看到均字了吗
# 上红魔！！！！
# 还能看出来安卓这个号更贵一点（指一命）
# 14是加了个散热
# 只有60hx屏幕
# 整机不到4w，真就用爱发电
# 过几个月就好了
# 折腾出结果来我才考虑三连，现在就先算了（doge）
# intel：这个我熟！
# 好家伙～13PM有机会做钉子户了
# 测极限功耗不用散热背甲？
# 《稍微》
# 我没有摸鱼，我们中午休息一小时（doge
# 心电图
# 提高测试上限才能测出高端处理器的差异
# 13pro已经停产了哈哈
# 厚了，重了，原来如此！
# 火龙果哈哈哈笑死我了
# 要笑死了哈哈哈哈哈哈哈哈
# 一看到这儿我居然卡了
# 期待！
# 好了，可以直接买mate50了
# 是不是打算发14Pro max ultra（doge）
# 游戏手机（不是）
# 980ti从最开始的5、60度，到现在的70多度
# 《甚至》
# 牙膏厂：这个我熟
# 对，玛德，PS5昨晚发现须弥出现PPT了
# ps52.0在瀑布场景都掉帧的，很正常
# 可以放心入13pm了
# 现在2.5w+
# 今年夏天30度只能开空调了
# 息屏显示可以再设置关掉
# 以前就有散热那后面不好挤牙膏啊（doge）
# 懂了，买14+
# 新版高一两千就改个散热
# 两块均热板的se3表示不服
# 双主板怎么散
# 既然摸鱼被发现了，那我就不藏了（doge
# 安兔兔图一乐
# 前面的，14pro的48mp不是四合一，标准拜耳的滤色片
# 接下来改提升到30w超级快充吧
# 14+ yyds
# 我们的手机要发热过后性能才会更强
# 室颤的心电图
# 《一见如故》
# 原神：征服苹果！
# 会烧瓶么
# 天玑8100nb(&gt;_&lt;)
# 安兔兔是兼容问题只跑了一半的分辨率
# 抛去散热问题，测出芯片的峰值性能，其他安卓也是用散热背夹跑的
# 14+
# 《在散热背夹下》
# A16:我成多余的了
# 好家伙gpu机会
# 给我狠狠打磨++++
# ！！！前方世界名画！！！
# 每一代发布时都是强无敌的
# 呀哈哈森林
# 12su李在赣神么
# 《2万+》
# 完全可能是芯片铺开了
# 我大mate 50呢！催更催更！
# 哈哈哈，13pm不用换了
# 哈哈 开心
# 高情商我们有自己的光追
# 巧了我也是
# 高情商：分辨率提升了
# 星期六直播不是说不测吗doge
# 我觉得14plus会打破神话
# 13mini可以等16pro了，哈哈哈哈
# 散热背夹哦
# 哈哈哈哈，还好没有买
# 众所周知，苹果的省电模式才是性能模式
# 手机用电脑芯片
# 《散热背夹》
# 有点狠了吧！
# 月销0哈哈哈哈
# 我还是更喜欢我的EOD（自豪
# 右下角可以开字幕
# 哈哈哈 反向一Q
# 越想越不对劲，旧瓶装旧酒
# 期待
# 心电图
# 14plus可能成为最香的机型了
# 天玑nb
# scene的悬浮窗瞩目
# 开启地狱模式
# 哈哈哈绷不住了
# 小惊喜 但不多
# 《站起来》
# 下次一定
# 仔细看飘哥满脸的嫌弃哈哈
# 《A16》
# 期待8+2
# （改进散热）
# iphone12也依旧很强
# 开局就是心电图啊
# 绷不住了哈哈哈哈哈还是买标准版吧
# 裂开，13pro都下架了只能入14pro了，我哭死
# 降压超频哈哈哈哈
# 到时候se4也得用这个，满血版
# 但是14有散热，接着看到后面吧
# 散热背夹，哈哈哈哈哈哈哈
# 14香啊 哈哈
# A11开始仿生到现在都没什么大改
# 两小时的那位，6:58 = 6:00？？？
# 1.5w
# 带个散热背甲得啦
# 直接三连
# 《均使用散热背夹进行散热》
# 旧屏装舅舅
# 但是预测14比13卖的好
# 《在散热背夹下》
# 高情商：喜爱有加（低情商：刀法精准）
# 《均使用散热背夹进行散热》
# 库克：修复省电模式bug
# 天呐，苹果做散热啦！
# 《UP主推荐广告》
# 王守义一夜封神
# 《喜爱有加》
# 直接拆机上水冷跑的（
# 《而A系列直接开摆（bushi）》
# 不是脚本?
# 8100属实离谱
# 库克想不到会烧屏？而且watch用了很久的技术也没见烧屏啊
# 真就好了一点点
# 14发布之后立马入手了13P，香，真香
# 然而就是一块铝板
# 安卓的分辨率就是搞笑的
# 须弥城那么大的压力跑图才占用50%，苹果nb
# 给iPad来点散热呗
# 但人家电池大还充的快啊
# g8 g8+ 这个我熟
# 《明显》
# 我超，
# c残次版也帅小龙好几条街
# 库存也是强的离谱的库存
# 一下致敬了两家企业，不愧是苹果doge
# 5c居然已经是十年前了吗
# 一块铝板，我真的笑死
# 主要是同行衬托 挤牙膏还是王者
# 火龙果
# 懂了，买14
# A16打A15！优势在我！
# 安卓电池大，冲的还快，碾压
# 反向优化
# 哈哈哈，游戏党灰心
# 60 能叫做高画质了？
# 14上个高刷是卖爆了，可14pro就没人买了
# 拿rog5来测一下
# 14plus
# 我12mini中画质也没问题啊……
# iOS只有60帧
# 真-13香
# 等着被14plus吊打
# 麒麟990
# 应该是用在m2pro上
# 日常没5G？阁下活在那个村旮瘩里？
# 0提升
# 给A15倒杯卡布奇诺
# 13香了起来
# 五年，等19
# 《8分钟》
# 手机现在的确用不上那么多性能了
# 1年前的电池必然有损耗啊，都是新机估计差距更小。
# 主要是米忽悠有对ios做过专门优化
# 所以，体验上有区别吗哈哈哈
# 哈哈哈
# 13PM香爆了
# 关WIFI？
# 后期可以通过软件更新解决吗！
# k50至尊版飘过！
# k50至尊版 飘过！
# 11代到12代挤了个牙膏
# 买老款或者8+1
# 原神移动端是(720p) 要是1080可烫死。
# 王守义十三香
# 火龙果
# 太热了苹果也要堆散热
# 14plus
# 专业
# 专业
# 全靠对手衬托
# 看过之后果断入手13pro。
# 《明显》
# 13香诚不欺我
# 8100：w还得是我
# 原神：叫你们做人
# 是不是AR眼睛要来了
# 张翰哈哈
# 深绿色的掉到10帧。。
# 怎么测出来的
# 超频了
# 好耶是车神！
# 13pro这么拉吗？
# 8g2完爆A16
# 电脑:原神就是弟弟
# a15 超频版
# 原神优化差，所以用来跑分
# 14pro牛逼
# 真的很有次世代的感觉
# 别plus了，续航的代价是手感。垂直边框而且爱13pm海沉了
# 苹果：我不挤，再等两年膏通也追不上
# 挣扎（降低亮度）
# 好像是因为架构团队给高通挖走了
# 今年没有降频版本说明工艺成熟了，良品率上来了
# 看来今年的soc还是8100+神
# 1w的手机只能玩60hz的王者谁行啊
# 《重新设计》
# 等14plus跌到2000买个打游戏
# 懂了：先搞个demo
# 苹果：被你发现了
# 但是安卓在价格上也有很大优势
# 然而实测功耗反而更高
# 高通：苹果真的，我哭死
# 自律的手机
# 看到功耗笑了
# 新机出来有很多都没有优化好
# 13Pro48℃
# 我全程开5G，自己不开别说所有人都不开
# 14太香了
# 《大哥不笑二哥》
# 红魔:啊对对对
# 库克：我大意了！下次你们家别拿首发了
# 王守义十三香
# 王守义十三香
# 虽然功耗高但是电池比苹果更大充电也快得多
# 果子重新定义息屏：息屏显示就是永远不息屏显示
# 这个还是类似于Android原生的aod，通知和动态壁纸都还在
# 是这样的，安卓打王者都开90帧和120帧，没人开60帧，因为太卡了玩不了
# 高刷确实没用(
# 骁龙8+的gpu打A15了？？？？
# 库克：挤牙膏是需要实力的
# 相当于m2最低功耗的2点6倍
# 哈哈哈
# 铁 人 三 项
# 日常用wifi的场景比用5g多，不会一直在户外
# 全 员 阵 亡
# 其实13pm拆开做个散热能和这俩一样，有个蛋用
# 这个测试红魔7SP，59帧通过
# 挤牙膏王子，库克
# +5+63+
# 友商加加油，不然苹果要一直挤牙膏了
# 烧屏？会动的
# 8100真的逆天
# 牙膏慢慢挤，明年岛面积缩小些芯片超频再水一代
# 高通：感谢苹果
# 上红魔就是不给苹果面子了（
# 有小字 都是在散热背夹下
# 要发力M系列芯片
# 8100：就你甜蜜叫8gen1啊
# 小米12su不配拥有姓名？？？
# 水果机下架13pro是有原因的
# 屏幕刷新率多少
# 《没落下风》
# 哈哈
# 希望有更简洁的
# 安兔兔G安兔兔上提升30%不知道怎么测试出来的
# iPad mini 6YYDS
# 还好，我下单的14pro退了
# 准备跑原神
# 入13pm等15算了
# 看8gen2了
# 感觉手机游戏都一个画质
# 13香，王守义一直是对的
# 没看前面嘛，都说了苹果开省电模式就是重灾区了
# 让你提前用了一年ip14 哈哈
# 期待14Plus
# 回归iPhone4三明治结构
# 14plus是60hz，当然比14pm省电啊
# 今年真就只更新了一个药丸屏
# 梦回骁龙888
# 散热背夹是重点
# 《一定优势》
# 为了让你更好的知道手机活着
# 散了个寂寞
# 因为气候异常，温度越来越高，不做不行了
# 欧文
# 没进步出什么新机型
# 只想知道发热续航容不容易烧屏
# 目前看14系列真没多大意思，要是散热没惊喜的话想买的还是等等重新上架买13pro吧
# x86架构yyds
# 红魔7sPro呢，可以稳定60帧
# ]
# 别说了，我三连
# 8+不错
# 哈哈
# 一定？这不天差地别嘛
# 在摄像
# 13pro也有自适应啊
# 因为今年格外热啊
# 火龙果
# 哈哈
# 哈哈
# 哈哈哈哈哈哈哈
# 哈哈哈就差1分还是误差
# 十三香！十三香！
# k50后段都成什么样了。。
# 重点是A系列乱摆每年性能稳坐第一
# GG火龙果
# 14加了个隔板，估计就是这个起到的作用
# 他测试的是能耗比，而不是散热，排除变量
# 我也卡住了，属于是蚌埠住了
# 什么系统？
# 没有麒麟的苹果在原地踏步
# 苹果再等安卓追上，然后再给安卓一个打击吧
# 手上的iPhone13 256香爆了
# 预订一个14plus游戏神机
# 《牙膏厂分厂》
# 再等一年了我
# iPhone高刷大部分场景都会限制在80帧，和没高刷的60帧差距不大
# 200尼特，会不会太暗了，刚才是300
# 强了0.2帧
# 完全无压力啊
# 巨大优势了属于是
# 库克：库存
# a15超频版
# 50% （一定优势）
# 奥利奥夹心主板
# +
# 果然13香
# 什么都没升，加了散热板
# 续航可比快充好
# 但是相机
# 过分了！
# iphone 14原名iphone 13 pro青春版
# 红魔：……
# 《诸神黄昏》
# 基带升级到x65了。
# A15太香了
# 13向
# 红魔6：嫌我开外挂？（doge）
# 苹果什么时候把电池加大到5000毫安呀
# “导出来”
# 《明显》
# gen2稳了
# 库克：库存没用完
# 火龙果
# 不过14和14plus屏幕帧率都是60帧
# 原来已经十年了
# 为什么我想起了猎户座2瓦功耗换寂寞的事
# 库存克星
# 游戏优化差，卡通画面都卡成这样
# iP「H」one
# 所以，有点极限了
# IPHONE 永远的神
# 【一定】
# 【一定】
# 苹果最开始可是做电脑的，现在回归老本行而已
# 上一次史诗级更新还是充电，从5W直接到18W！！
# 懂了，買mini6
# 刺客打钱！
# A16CPU，放到双层板外面了？
# 搞了块铝合金板，隔壁微机分拆解了
# 60刷新率
# 已下单 要到11月份才会送
# 绝对烧屏
# 哈哈哈哈哈
# 秋天来了，来自大自然的散热
# 哈哈哈哈哈哈
# 13pro真香
# 我直接等20
# 懂了  A16是小白鼠
# 左边什么手机
# 《厨子：软硬件全面对标安卓！》
# 《抛开事实不谈，难道A16真的就一点提升都没有吗？！》（doge）
# 《地狱绘图》
# 最强游戏机是mini6
# 原神没优化
# 每一年都降20%
# 苹果公司一直都是做电脑的
# 安卓阵营玩游戏最好选天玑8100
# 我觉得可以
# 懂了，A15换制程然后超频就是A16
# 火龙果
# 手持ps5须弥不卡
# 但是我们有快充和大电池
# 14 PRO 有灵动岛加持
# AMDyes！
# D 系列 yes！
#      在在在在在
# M系列 yes!
# 14比13pro笑死我了
# 有脚本同步
# 没人买，哈哈
# 骁龙8+还是有能满帧的机器的
# 多了一块金属挡板
# 1.5倍的功耗，这叫一点
# 此处8+最强
# 《站起来了》
# 游戏模式
# 我仔用我的XR玩原神，，跟个暖手宝一样，，，所以考虑换一个14了。。。
# 哈哈
# IT之家牌面！
# 果然13香
# 知道了，买13
# 懂了，A16≈M2，四舍五入就是M2芯片
# 听说是上了vc均热板
# 全在等海思麒麟和联发科 我哭死
# 是不是游戏在挖矿
# 大米评测小米12Pro天玑版，王者荣耀表现比12SPro好一些
# 苹果：学一下火龙的反向升级
# 日常能不能是4g？
# 13没有灵动岛呢doge
# 喜爱有加可还行
# A16——M3 Max Mini Lite 青春版
# 哈哈哈
# 再看一遍娱乐一下
# 决定了，等15Pro！
# 我也是根本不玩手游。。但买了14pm，不过我是拍照居多
# 不要叫息屏显示了，叫亮屏显示吧
# 屏幕和其他元器件被中板隔开了
# 懂了，14plus是游戏机
# 14plus恐成最强游戏手机
# 还没更新优化a16
# 安卓阵营的电池容量可大多了
# 王守义诚不欺我也！
# 你永远可以相信苹果的刀法，新的就是好
# 买了后悔了
# 刺客打钱！
# 之家好评
# 说明真没其他做的了，就看各家安卓努力追赶了
# 天变了，苹果开始做散热了
# 13pm一年了电池也有损耗了吧
# 库存克星
# 8100，神U
# 8+真不错诶
# 拣了芝麻丢了西瓜
# 安卓：？？？
# 一台iPhone 14能买三个k50u
# 苹果：慢慢来
# 人话：超频
# 人家充电五分钟充满了
# 哈哈哈哈
# 百分之3 轻松
# 火龙果了 属于是
# 日常不用5G
# 懂了，13加散热背夹
# IT之家666
# 爱碰
# M3：正是在下
# 真牛逼啊！
# 这个更容易烧屏，这样显示的话
# 是不是还没有吃配好，毕竟手机才刚出。
# 13pro max真香
# 皮衣表示很赞
# 辛苦了辛苦了
# 5分钟的可以左转眼科了
# 笑死了哈哈哈哈
# 手持13PM笑出声
# IT之家的面子给足了
# 苹果终于注意到续航和散热了，感人
# iPhone直接把散热板跟中框连接了
# 感觉还是工艺达不到预期的锅
# 屏幕和刷新率的问题吧？
# 火龙果
# 安卓充电块
# 14成了
# 不愧是开五菱
# XR又要再坚持一下下了
# 3
# AOD＋灵动岛就注定14比13香
# 火龙果
# 14p最佳游戏机
# 更大的屏幕更大的功耗
# 对于高通来说已经是外星科技了，怎么摆都没事
# 堪称手机届的CLTC?
# M1:喵喵喵。。。。。
# 说13 pro接着用的真酸
# it之客2
# 由于没有对手开始整活了hhh
# 5到4可不就是20%么。
# 设备负载：致死量
# M3ultra(
# 牙膏用完了
# 果然十三香
# A11路过
# 一进须弥城就掉帧
# 哈哈哈哈哈哈
# 前面的，红魔带风扇不防水啊！！！
# 总结就是：移动端原神画质就是寄，等同于PC端低特效
# 科技以超频为主
# 15香
# 为了看这期视频，我打开了省电模式（性能模式
# 超频版
# 因为最近夏天很热
# 14plus绝对游戏机无敌，替换8p的
# 哈哈哈哈太药膏了
# 新牙膏厂诞生
# 把红魔7spro搬出来
# 爱疯5saber
# 我存了好几天的币了，想投测华为的视频
# 这样看来13更香了
# a14++，a14超频超频
# 明年的618，14应该会延续13的爆款，毕竟多了2g运存
# 领先安卓十年的A系列
# 那大屏的plus,撒热应该是目前苹果里最好的了
# 13pro用户笑开了花
# 能耗比也是8100最高
# 每日s22（1/1）
# 懂了，买红魔
# 直接崩了
# 前有娱乐大师，今有娱乐兔
# 十三香！
# 安卓机就别叫了，我刚从小米旗舰换过来 能一样么
# 以后要为MR做散热/doge
# 好快 5c已经10年了
# 大电池安排
# 草，这个功耗
# 13proMax用户笑了
# 不间断玩8小时手机 我是受不了实际上续航超10小时没问题
# 铁人7项
# 手机按碎了
# 稳定
# 安心用13pm了
# 哈哈哈哈
# 不用手机最环保
# 8100很秀啊
# 为什么要用散热背夹啊
# 完了，成试验品了，
# 牙膏厂同款思路
# 非常眼熟
# 果然13香
# 《散热背夹下、》
# 为什么我的安卓是810
# 这说明明年没有A17了（bushi）
# iPhone快乐5g
# 但是K50U充电快
# a15牙膏挤多了
# 不可能，主要赚钱的还是手机
# 主要是没对手随便提升一点，自己玩去了
# 手表也可以
# 安卓电池大呀
# 注意，这是在120Hz下跑的
# 骁龙888:我成替身了？
# iphone16pro
# 均使用散热背夹没看到？？？
# 贴的石墨贴 外博有拆的了
# 哈哈哈哈哈哈
# 反向优化
# ios16没优化好吧
# 好的等明年的15了
# 哈哈哈哈哈哈哈
# 这还没请出游戏手机
# 总结：等14plus
# a系列的对手只有自己
# 三星s22
# 不要再进化了 安卓已经追的很吃力了
# 主要是底子够厚，开摆也能吊着打安卓系
# 主要是没对手 就开始挤牙膏了
# 学到了牙膏厂的精髓
# 挖矿啊
# 好的  买14PX
# 怎么回事捏
# 到达世界最高峰
# 13PRO电池都用了快一年了，寿命都下降不少
# uzi不压对面补刀 等于被压（
# 原神PC端体验感是拉满的
# 表示日常不玩游戏 手机一个游戏都没有
# 1440p甚至还低了一帧（doge）
# 俗称：挤牙膏
# 红魔7spor：小米一边去，让我来
# 13香是真香啊
# 真是13香
# 13买的真值啊
# 主要没压力现在安卓a15都打不过
# 电脑不卡
# 就多了5分钟  算了吧，还是 A13 吧
# 13PM加个背夹依旧无敌
# 严重过高！！
# 可是，没有高刷，日常用
# 有一说一，安卓有快充
# 骁龙8+还可以啊
# 懂了买16
# 以前a13a14a15首发测试不也是和上代一样
# 《13香》
# 优化没到位
# 以前就没有散热
# 13pro真香
# 13pm最大赢家
# 红魔7s和7spro直接全程满了解一下
# 安卓电池也大啊
# 加了散热算是提升性能了，哈哈
# 散热背甲
# 期待2024xr壳单层主板a16的se4
# it之家好评
# 完全一致
# 台积电nb
# 安卓便宜还有快充
# 林pack
# 墨鱼
# 苹果:没想到吧，我学到因特尔的精髓了
# 可能连牙膏都没去买吧（bushi）
# 手里的13pro越来约香
# 40的延迟 离谱
# 库克随便出个新版本系统就能拉开两个CPU的差距
# 害在乔布斯
# ios16没有优化
# 开了这个头往后每一代标准版都将搭载上一代pro的处理器，估计就算iphone15一样不上高刷
# 反向优化
# 没有灵动岛啊13
# 拿去挖矿！
# 学会高通了
# iPhone 14:我觉得我行了
# 但是14没有灵动岛啊
# apple:老子学会了！
# 我3060的电脑都掉帧，也不知道怎么有手机敢说自己能征服原神
# 哈哈哈哈哈哈哈哈哈
# 3
# 但凡14上个高刷！绝对卖报
# 卧槽已经十年了吗
# 完  全  一  致
# 刀法不错啊
# 烧屏挂鱼喊我
# 反向升级？？？？
# 看树根的差距
# 全靠高通衬托
# 明年iphone15用m3
# 等一等友商
# 靠~
# 废仓符合
# 火龙
# 14plus面积大，可能更强
# 你功耗高
# 写个程序跑
# 《弱一些》
# 你兜售的样子很狼狈（bushi）
# 13红色在此，这个红色真的很低调，但太阳光下很好看
# 待机续航很重要
# 待机续航
# 我超
# 王守义十三香
# 红魔是直线
# 可以 13香
# 小米10有7w
# 火龙果
# 高情商：施魔法
# 烧屏预定
# 啥时候火龙888给个省电模式啊
# 喜爱有加
# 就等14proMax
# A16慢慢优化就好了
# 一命夜兰
# 分析A16表现（指严刑拷打）
# 哈哈
# a14都比8+好哎
# 机房上课看手机
# 又是下克上了
# 13香诚不我欺
# 真就降压超频啊
# 在不影响续航的情况下减小电池相当于变相减少充电时间了？
# 设计个脚本吧
# 谢谢希望8gen2锤爆他
# 谢谢希望8gen2锤爆他
# 因为太强没有对手而开始整活了
# 谢谢希望8gen2锤爆他
# 它不是一直亮的
# 谢谢希望8gen2锤爆他
# 苹果胶水
# 安兔兔打钱
# 因特尔情亲传授7mm++++++++++++++工艺，背后的故事令人暖心
# 我在期待什么
# wtf前面的，我的siri也出来了
# 《iPhone 14 Pro Max》
# 优化没到位
# 哈哈哈 去年买得13pm没白买
# 测试人的续航..
# 简直梦回a8
# 所以说苹果必须要比安卓强吗？
# 太牙膏了，今年
# 芯片也开始挤牙膏
# 散热背夹
# 超频了
# 我怕会烧屏
# 不会有人玩游戏只玩10分钟吧
# a17叫理塘（
# 平常玩会关了5G？？
# 2022年下半年还没高刷 绝了
# 高通机会来了
# 原神……
# 主要没对手了，麒麟要是一直生产可以竞争
# 频率保持住了，功耗肯定得上去一点
# 给孩子开发个连点器吧
# 说屏幕导致的不愧是苹果驯服的
# 又是10%？
# 火龙果
# 盲猜plus更强
# 今年真的没必要买新机了
# 苹果：友商还得追两年
# 人家电池大啊
# 游戏神机还是算了，双层主板
# A15 &gt; A16了属于是
# 还是有掉帧的感觉，iOS16
# 13pro买对了
# 会变成4g是开了自动5g
# 8g1 yyds
# 去年A15GPU牙膏挤爆了 今年没得挤了哈哈
# 电池容量少了，续航还强了
# 高情商：Intel的六代到七代
# 严谨
# intel：这个我不熟啊
# 懂了，A系列是副产品
# 14plus才是隐藏旗舰！
# 主要是安卓没有能打的
# 打脸前面的一位
# 给你高通一个机会doge
# bug竖屏跑的
# 烧屏
# 870我熟
# 13pro香炸了
# 原神开测
# 膏通：没事，我再退两步
# 会不会是几个人合伙开一个合伙兑钱整的
# 米哈游：没有优化，众生平等
# 苹果甚至也在等他，泪目
# 但是安卓便宜啊
# 2.6w+
# 懂了买14
# 苹果：让我们放缓脚步，等等安卓(ღ˘⌣˘ღ)
# M2青春版
# 苹果：感谢高通
# 坐等14plus了
# a10这个我熟
# 《一定优势》指2W左右
# 开个AOD测啊
# 哈哈哈哈
# 膏厂：勿CUE
# 60帧的游戏神器233333
# 功耗上去了啊！
# 2.5w摸鱼玩家
# 袖口有线头！！！！
# 懂了，M3要用Zen3架构
# 有高刷的竟然还给更小的电池，这刀法
# 我都开4g   5g瞬间没电。。
# iPhone14：其实我是iPhone13pro青春版
# K50是什么神器？
# Pro机型有自适应刷新率
# 火龙果
# 火龙果
# 火龙果
# 才三瓦？？？
# 这是测的极限性能，用散热背夹很正常啊
# 而且安卓有散热啊
# 可貌似就是高几帧doge
# 然而我不用5g哈哈
# 14plus致命的60hz的屏幕，如何让它成为游戏手机。
# A系列：请叫我M3 mini
# 骁龙8：眼熟
# 挤牙膏啊我靠
# 苹果1w的功率跑出骁龙888满血的性能
# 从m1开始A系列芯片是从m系列缩水下来的
# 14plus，继8plus后的下一代游戏神机
# 懂了，买13pro
# 西皮尤
# 左下角过分了
# 860与870的分别，上散热因为超频了，dogs
# 哈哈哈哈哈
# 哇哦
# 13pro用户笑开了花
# 买游戏机建议去买红米，没高刷日常使用简直就是折磨
# 午安 2W摸鱼人，摸鱼摸到老板宝马换青桔
# 拿5c听歌算用吗
# 七年前(警惕)
# 2w＋
# 红魔：有我压不住的游戏？
# 这次换iphone开摆，高通机会来了
# 很期待plus游戏机
# 14plus高刷都没有  还最香机型
# 坐等麒麟9010
# 库存克星
# 哈哈哈哈
# 继续挤牙膏
# 13香13
# 计时手机牛
# 因为是在想不到做啥了
# 啊这散热背夹就离谱
# 哈哈哈
# 主要还是散热好吧
# 买什么14，最近上13pro
# A15 永远的神！！
# 安兔兔没适配 竖屏渲染少了一半的像素
# iPhone 14的H大写了
# 原神在手机上永远无法征服了
# 因为高通太拉了
# 13por都用快1年了王者还不支持120hz
# 13少一核啊 当然稳一点
# 不玩原
# 14 puls买定了
# 8gen1独自美丽
# 期待14 plus 和14pro max
# 都不讲降亮度了
# 16省电模式功耗还可以
# puls暂时买不到
# 你这是开空调的温度
# 全球变暖
# 散热现在是秋天
# 哈哈哈哈
# 看完视频只觉得13pm最香
# 天啊gpu这么强
# 库克：就你话多！！！！
# 明白了  买15
# 15香
# 慢速吟唱
# 红魔：这测试太简单了
# 哈哈哈哈哈哈哈哈哈
# 《苹果要完了》
# 火龙果
# 旧瓶装旧酒可还行
# 库克：我大意了！下次你们家别拿首发了
# 甚至牙膏盖都没打开（
# 找不同：请第一眼找出iPhone14 doge
# 《m2降频版》
# 主要是现在骁龙一直干不过A系列吧
# Intel：这个业务我熟
# 别问，问就是致敬经典（doge）
# 库克：我不但不挤牙膏，我还差点吸牙膏
# 无  声  吟  唱
# 上手体验
# 懂了 我的12还可以坚持三年
# 少1w了。。。。。很多了
# 很小=根本没有
# 上手体验
# 哈哈哈哈哈哈哈
# 上手体验
# 超频了？！
# 十三项
# 上手体验
# 《明显进步》
# 上手体验
# 上手体验
# 懂了，十三香
# 哈哈哈哈
# 《反而》
# 十三香
# 买12的大怨种
# 肯定是散热背夹下啊，这测的是芯片性能又不是模拟正常使用或者玩游戏
# 上手体验
# 摄像头挡那么多画面？？？？？
# 上手体验
# 十三香诚不欺我
# 安卓的屏幕不是很大吗，为啥分辨率那么低
# 14pm或者14p会更恐怖
# A15：我只是想等等
# 生产太多了没办法，只能去库存给14也用上A15了
# 暗示以后牙膏都不带挤了
# 诸神黄昏
# M1中高画质直接热翻
# 《明显进步》
# 一见如故，壳子都懒得换
# 《一点点》
# 14香
# 降档补油
# 秒杀3星
# 挤牙膏究极版
# 但充电要2小时
# 超，买A15
# 经典手机测试软件开发商，米哈游是吧
# 原神出来前崩三的掉帧炮也被拿来当测评用过
# 看了这个测试基本上买13就足够了 最多上14 没必要上pro
# 《反 向 牙 膏》
# 完全一致
# 坐等明年15
# 是摸到iphone12不是A12
# 《一点点》
# 哈哈哈哈哈哈哈
# A15.5
# 14香
# 反向升级
# 13价格香爆
# 哈哈哈哈哈
# 原神的优化是真的不差只能说
# 14pro max 为什么不测
# 14plus宣传页，续航在iPhone全系排头名（全系就包括pro系列）
# 《13香》
# 币比收藏还多……
# 哈哈哈哈哈哈
# 30度直接G了
# 提升了又感觉没提升
# 室温30度别玩游戏了 一手汗 躺着睡吧
# 是都使用了散热背夹，不是只给14使用了散热背夹，所以提升是肯定的了
# 《散热背夹需自行购买》doge
# 王守义诚不欺我
# 真就13香了
# 3.0把画质调高了 直接压力上来了。。
# 小游戏
# 只是之前库存太多了
# 牙膏学起来了
# 3050都卡死了
# 13promax还是香啊
# 你在暗示8代（A17）牙膏挤爆？
# 没有倒吸，他真的，我哭死
# 众所周知iphone都是两年一提升
# 哈哈哈
# 感知不强
# 过分了啊
# 什么时候出mate50！
# 下一代可以叫奥林匹斯，火星最高峰
# 哈哈哈哈哈哈
# 没事在等一年
# 吸牙膏！
# 11代酷睿石锤
# AMD锐龙6000移动端CPU:不是我哈！先说好
# 全靠高通的衬托发现A13都能再打打
# 高情商：真正的省电模式
# 散热不加强以后都不会买苹果了
# 懂了，买14，满血版A15
# 看来目前果系最强游戏手机还是 14plus
# 你测了个寂寞，功耗是实时的
# 13的时候不也是这样吗？pro系列都双层主板
# 14plus游戏机了
# 友商加加油，不然苹果就开始挤牙膏了
# 我的13pro能坚持个几年
# 《吸牙膏》
# 14plus屏幕更大，稳定度估计80+
# 去年买13香爆了
# A16是真拉啊
# 问题是拿手机玩，一般都是5g室外没空调
# 看来限制苹果芯片的只有散热，如果按照安卓厂商的散热，性能还得上升一大截
# 上次
# 广东的日常温度
# 两边颜色直接不一样
# 哈哈哈哈
# 在乎这些干嘛，1W买个就是打打电话拍照就行了
# 红魔功耗10w53℃拿的住吗？
# 3080一点都不卡（）
# 挤牙膏高通也追不上
# 感觉是优化问题
# 桌面级别的性能提升
# 工艺瓶颈
# 十帧甚至是九帧
# 苹果就是很直接的告诉大家，手机没必要一年一换，两到三年一换就行了，环保
# 小米yyds
# 天玑8100
# 我宣布，13pm新一代钉子户！！！！
# 但是没有高刷，所以还是13pm香
# 哈哈
# 它真的在省电，我哭死
# 更烫手了
# 18：21不谢
# 哈哈
# 哈哈
# 游戏模式都拉了
# 库克：去年挤多了
# 骁龙下一代处理器有机会了
# 天玑8100：你们都不环保
# 完了其他厂商没有活路
# 拆机要拆背板玻璃
# 14pro是不是没有均热板
# XR
# 所以手机也快用m了
# 没有麒麟苹果在原地踏步
# 15上高刷 pro就不用卖了
# 8gen1+封神了
# 高情商:喜爱有加，低情商:清库存
# 《Apple：未来5年把M系列芯片放进iPhone》
# 十三香！
# 懂了买13pro
# 14加钱买了散热
# 等游戏更新吧
# 14plus应该是一代神机了
# 新晋牙膏厂
# 哈哈哈哈
# 注意看晓龙8+ 和8100
# 就一块金属板
# 懂了 买15
# 技术指导：Qualcomm
# 这不8gen2的gpu大概率超过a16了
# 原神吃内存时序，我1060都能满针时序15
# 只因出
# 只因了
# 苹果跑4w 安卓估计6w了
# +3
# 《8寄1带散热背夹没有8100强》
# 电脑毫无压力（指全低特效）
# 只因pu
# 哈哈哈哈哈哈哈
# 《反而》
# 石墨贴
# 散了个寂寞
# 台积电的广告话术
# 单核提升8%
# 拉链+＋＋工艺
# 快七小时
# 玩游戏旁边一个黑块已经很不舒服了
# 烧屏
# 同样6k+的价位 13pm比14plus香多了 不觉得14plus会像11一样卖爆
# 反向省电
# 坐等15
# 哈哈哈哈哈哈哈
# 看了拆机 14有优化散热 14pro散热没啥变化
# 8100笑再最后
# 懂了，买13pro
# 原神yyds
# “20%””
# 库存克星
# 不烧屏也不耗电，用过常显Apple Watch的都知道
# 测试软件
# 库存克星
# 懂了买13
# A系列 yes！
# 5cyyds
# 哈哈
# 手里的13pm又香了
# 隔壁拆了14，就多了个中板连着边框
# 哈哈哈哈
# 这么想，14Plus或成最大赢家
# 给了！
# 芯片拉了，只能做做散热拍照等等其它功能了
# 看来0洞岛要离开我了
# 哈哈，iPhone14刚到手，有这么值吗？
# 只因
# 买个十几块的风扇夹
# a15s（same）
# 所以通道贷款也是吹牛皮的
# 20％了
# 方向对了，但又不对
# 我又懂了，明年的iPhone15用M2芯片
# 应该测下30摄氏度，5G环境
# 小何:有点恐怖
# 灵 魂 发 问
# 最稳定但是性能最弱啊
# 比基金好(
# 火龙表示你也有今天
# 那么14plus就是很可以的游戏手机了
# 苹果：我这次就卖个灵动岛
# 窝草！农！
# 均热板。有人拆完了
# 左下角，均使用了
# 哈哈哈哈哈
# 13pro真香
# 《严重过高》
# 巧了 我直接下单的14蓝色256 24免 什么pro 都靠边站
# ++++++++++++
# 8g2有望反超
# 我觉得能做到这样，并不是散热的问题，而是CPU功耗降低了，需要多一些时间才跑到需要加载的位置
# 续航位列前三但不是第一……领头……
# 懂了，芯片不属于机子本身
# 总结：高通太拉了，苹果挤挤牙膏等一等
# 刚买了a7c没钱买手机了
# 懂了，买13pro
# ⌓‿⌓那不使用5G，续航不是更久
# 灵动岛：怪我，都怪我
# 小米 12spro 或者 iqoo10pro 呢
# 烧屏的那个，AW到现在也没有烧屏啊
# 世界名画
# 安卓一堆机轻松上90多
# IPHONE 14 PLUS
# 我又不玩原神
# A15 KS
# 已经有拆机了，14有散热pro反而没有
# 13的继续得瑟啊
# 13pro多个高刷已是绝杀
# 《iPhone 15.2》
# 《进化》
# 给！
# 让安卓在追两年
# 致敬骁龙
# 价格也更贵了
# 王守义yyds
# 超辣库
# 8100厉害了
# 这大概就是爱吧，对高通的爱
# 8100才是真正的环保机！
# 8100yyds！
# 麒麟可信了
# 但是安卓这动辄120W的充电，这波苹果会出问题（除非提前剧透高通的情况）
# 哈哈哈哈哈哈哈
# 这么一看13pro真好看啊 14PRO这摄像模组不协调
# 换云飞来啊
# [ohhhh难崩0.3]
# 骁龙：？
# 《牙膏挤出来又缩回去了》
# 大号Apple Watch (
# 明年15用m3芯片实锤了
# 《60帧》
# 13狂喜
# A16 YYDS
# 懂了买13pro
# 让安卓先追上一点
# A17更香
# 60帧数的王者.....
# 天机yyds 超越苹果
# 王守义:没想到吧，14香我也注册了
# 等很久了
# 王守义诚不欺我
# 今年芯片产能不够
# 高情商：媲美m2
# 不调好就发布
# 坚持不了1天
# 苹果：我改行做电磁炉了 别催了
# 《一定优势》
# -13
# A15香坏了
# iPhone能开120帧
# 跟intel学，将功耗不提升性能，也预示着手机芯片性能过剩..
# 还是王守义有远见
# a15摆两个，高通猜样追上
# 牙膏挤回去了
# 14NM++++++++++++++++
# 更费电的AOD
# 游戏发烧友会用60hz的屏幕打游戏？
# 王守义yyds
# 原神：你不好好反思一下吗
# 库克=库存克星
# 简单的数学问题
# 我的7P拍花居然我766强
# 真外星科技！
# 环保是真不理解，指前面的
# 强了0.2帧是吧
# 手持SE
# 左上角挡字了
# 为什么要闭着眼睛说话（
# plus256才7000多
# 再挤牙膏高通就要赶上来啦
# 测省点模式，笑死我了
# 哈哈哈
# 成替身了
# 手机CPU里没有对手了 开始自己玩起来了
# 果然13香
# 原神高画质开60帧
# 14plus搞不好要封神
# 手持iPhone5c 蓝色 手感太舒服了
# 今年相机提升大
# 是石墨贴了
# 没记错的话 发布会说plus也有改进散热
# 没有强调，只是提了一嘴…
# 《一定优势》
# 懂了，后年买se4
# 好一手牙膏
# 但是一台14pm能抵快三台k50u了
# 14plus
# 高情商：优化  低情商：挤牙膏
# A15超一下频，加一下散热，诶！A16！
# 谢谢，我买的14.
# Mate 50，昆仑山
# 太阳：你等着，明天就从西边出来
# 这温度自从8+出来以后就没见过了
# 13香红红火火恍恍惚惚
# A15 yyds
# 果然只能买单数年
# 懂了，买14
# 应该是原神还没有适配a16啊
# 14有120hz就是真香机
# a16是边角料是吧
# 我换算了一下，能效比接近20%了
# 14
# 一样的GPU就离谱
# 实验田，指移动端最强
# 主要是k50才3000，i14要七千多
# 8gen2：等着
# 相同电池容量下续航巨幅提升1.7%
# 安卓远景画质已经比ipad好很多了不知道ipad咋回事
# 可以试一下WIFI下的续航，基带的续航不一样
# m2 青春版
# 王守义诚不欺我
# 总结:等15
# 我没戴眼镜
# 苹果：再等友商两年
# 好多似乎
# 20w警告
# 然后开始7年的4800w
# a16=a15+（
# 看评测就直接告诉你买13pro或者pm就好了！
# 火龙888直呼内行
# 冷知识，K50只要3000块
# 没事我摸鱼老板在旁边也不怕
# 牙膏要慢慢挤
# 直接14plus
# 加卡加卡！
# 哪里有saber
# 越来越期待plus了
# 摸鱼+1
# -++
# 你别管他挤不挤牙膏，主要他是最强的芯片
# 《反而》
# 哈哈哈哈哈哈
# 没有均热板，就是内部设计变化改进散热。
# 摸鱼了
# 明年iphone 15 青春版 还是A15
# ……120帧玩习惯了，60帧太低了
# 才30度
# 买了1万的手机，舍不得开空调？
# 红魔：带爷去蒸个桑拿
# 毕竟全球变暖了
# 有没有无散热的数据
# 红魔99
# 米哈游去给他们整个活，草，走，忽略（
# 更不如a15了啊
# A16=真 A15官方超频版=整体性能提升8%
# 1 3 人 完 全 胜 利
# 得到了牙膏厂多年的真传
# A16:A15官方超冒烟版
# 买14也不玩原神
# 刀法精湛库厨子
# 原神到来
# 散了个寂寞
# 可是安卓中画质是苹果低画质
# 施了魔法？优化太差！
# 总结：等15
# 牙膏慢慢挤嘛
# 120呢
# 应该去跑沙漠 大核直接起飞
# 手机都有热设计的，但区别都不大，毕竟热量导出到最后都是玻璃板和空气之间的被动换热。想要不降体验玩手游都得带背夹
# 没高刷！
# 1w块钱买试验机
# 补刀没拉20刀就是落后
# 犹抱琵琶半遮面
# 感觉像是a12和a13的提升
# 哈哈哈
# 高通从888开始如果使用的是台积电，就没有火龙一说了
# 1.6万人一起观看
# 测下充电
# 直接只因
# 高情商：旧屏装旧酒 低情商：一模一样毛都没变
# 麒麟9000就别碰瓷了
# 均使用散热背夹啊 又不是就14用了
# 环保
# 没有竞争对手了属于是
# 60刷新率的游戏神机，我笑死
# 未来一个月
# 都用散热背甲跑
# 牙膏传承
# 上个888“顶破天”
# intel直呼内行
# 动画做得不错
# 看完XR在战一年
# 我咋看不出领先
# 一阵电竞
# 因为须弥没有一座山是实心的
# ++】
# 哈哈哈哈
# 确实第一次，乔布斯要是看见不知道会说啥
# 哈哈哈哈哈
# 哈哈哈哈哈哈哈
# 逆天，甚至挤都不挤一下
# 14plus我不敢想！
# 哈哈哈哈
# intel：库克你明天来我这上班吧
# 稳定牙膏，明年a17还是10%
# 连夜下架13PRO
# 开始有点接受不了了 我的电脑竟然跟手机性能差不多……
# 没有优化过
# 比较费测试员
# 上红魔呀
# 优化在本来就差的基础上又差了很多
# 极限性能测试都是有散热背夹的
# 不锈钢导热不如铝合金，很正常
# 不过iphone目前的确很容易烫...
# mini6最大赢家
# 骁龙太拉了，苹果没有进步动力，去其他领域发展了
# 我的麒麟9000呢
# 吃鸡:我当年也是这样过来的
# +
# 红魔直接满帧，就是功耗很大
# 娱乐兔
# 王守义诚不欺我
# 高情商：一见如故    低情商：壳都懒得换
# 库存克星
# 芯片拉了，可不得做做散热
# 买个超薄散热背夹都行
# 到时候给
# 苹果：都熟了
# 必须给了
# 草还是13香
# 14plus
# 8100也太秀了吧
# 哈哈哈哈哈哈哈
# 哈哈哈哈
# 2.2w
# 哈哈哈哈哈
# 哈哈哈哈哈哈哈哈
# 次品m2？
# 8gen1是60帧的还是120帧的
# 但是不影响我不开
# 提前 the end
# 璃月港跑图
# 竖屏bug 跑出来的
# 牙膏挤得好吖
# 感知不强
# 五到四很难了，工艺
# 和Lumia系列类似，记得当年我的830和638就有这种aod，还可以设置成灰度
# 基本上一模一样好吧
# 就是手表的显示
# 苹果的腿好看啊
# 13yyda
# 芯片功耗压不住了，必须得搞散热了
# 14没高刷直接劝退
# 外星科技
# 「可以用b站自带的字幕」
# 前排提示k50卖3000块
# 1.6w
# 1.6万人了
# 手机屏幕玩游戏高刷感知不大
# Redmi k50 ultra征服原神
# 大伟：听说原神被征服了？更新！
# 14pm:我不配出现吗？
# 游戏模式实锤了
# 官方降压超频版
# 天玑8100牛逼！
# 手机核心就是来试水的
# 13xiangq
# 须弥的地形组成远比其他地图复杂，肯定更吃性能
# 王守义：都说了13香
# 12mini再用一年
# 但是他是只能在4G网络下的呀。
# 15+
# 13香名不虚传
# 果然是十三香
# 更膏
# 笑死，14系列唯一险胜的一节
# 王守义yyds
# 14plus预定真香机
# 同时散热也拉跨
# 摸鱼
# 懂了，买13
# 亮屏显示
# 15香
# ipc从A12到A16都没变化
# A15一代神u
# 应为IP13是残血的A15 所以用13PRO对比
# 14 plus预言直接封神
# 1.6万人
# 好家伙，爱破也开始倒吸牙膏了
# 哈哈哈
# 哇哦
# A16没散热石锤了
# 最多算是蹲起来了
# 全球变暖
# 懂了，这是在向10年前的苹果致敬/doge
# m1 padpro90帧加散热背夹还能压住120帧普通背夹都压不住
# 上手体验
# 上手体验
# 天玑牛逼
# 原神行为
# 《降低功耗》
# 刀法指导：黄仁勋
# A15诚不欺我
# 上手体验
# 反向升级
# 说少屏的都是没用过14pro的，放口袋会黑屏，拿出来才会显示，根据光线来的
# iphone A13香
# 高画质60帧实在没难度
# 安卓出120帧了吗？
# 一个连三a都算不上的游戏
# 反向升级
# 库克也不想学小米手机到处烧
# 总有些乐子认为自己比飘哥懂手机
# xr才是真游戏机
# 13也别买 等后年16
# 这个差距是新机没有优化好而已过段时间就好了
# 懂了买k50
# 8plus:新一代游戏机是吧
# 没有魔法，因为根本没优化
# 除了没120，都好
# 以后吃手机配置的游戏肯定越来越多，性能过剩要成为梨历史了
# 14香
# 14plusyyds
# 《差不多》
# promax才是续航之王
# 《就这样被你征服》
# 刷新率？
# 懂了，买iPhone15
# 13香实锤
# 居然都10年了
# 14plus 封神
# A17：LTC
# 还是13香，诚不欺我
# 牙膏厂:你礼貌吗？
# PS5跟不上米哈游的技术力
# 1年前的机器电池肯定有损耗啊，都是新机的话差距肯定更小。
# 芯片进步不了，只能做别的了
# 别红魔了，隔壁早就测了，一样掉帧
# 这我很难吹啊
# 13pm续航已经第一了。这次还提升一点不错了
# 懂了，马上买14
# 讲一下高通骁龙8Gen2芯片？
# 居然
# 喜爱有加
# 只因
# 乔布斯后再无苹果
# mhy：懂了，这就开1080p（
# 总结：买13ProMax
# 865和870的关系
# 13香名不虚传
# 高通：菜
# 13p都卡了
# 中画质我8100都能60
# +
# 降亮度显示
# 14plu更香
# 5
# 看来还是我的13rm香
# k50香（doge
# 没优化
# 为啥不开120呀？
# 安卓中画质勉强算苹果低画质
# 什么时候出D系列，AMD
# iPhone5C手感无敌
# +
# 外星科技
# 牙膏厂亲传
# 这图一出来我还以为90帧呢。。。
# 主要是高精度也没多高，画质都一样拉
# 反向升级
# 注意，iOS16版本优化也是有问题的
# 我的天，14pro游戏性能拉了
# 手机处理器性能过剩 已经到顶点了
# 13pm不打游戏太香了，散热不是问题
# 我不玩游戏啊
# 省流：14拉了，13香
# 14plus上单层主板应该没问题
# 8100运行大部分主流游戏都基本满帧了，手机原神玩家当我没说
# 14:就你叫pro
# 怎么不放个红魔7spro
# 把红魔放出来
# 低情商:安卓阵营太弱了
# 多核功耗10以上
# 运行内存多大
# 《反而》
# 啥也别说了，来，启动原神配置拉满
# 左下角小字瞩目
# 记得看左下角
# 分析得好
# 苹果的处理器一直排名第一，就算挤牙膏安卓照样超不了
# 台积电3纳米苹果不满意，其实也意味着摩尔定律没了，所以要散热
# 膏通直呼内行
# 遥遥领先于上代
# 13太像了
# 微机分：就一铝板而已
# 有没有想过14和14promax是屏大小的问题
# 红魔：？
# 真的要用手机玩儿游戏吗
# 我甚至都不开
# 外星科技
# 懂了  买13Promax
# 王守义诚不欺我
# 但是没高刷
# 真神
# 等iPhone 15才是正确选择
# iphone散热是真的不太好，打游戏给烫的
# 8100yyds
# 无敌是多么寂寞，做了这么多年大哥，想放松一下
# 王守义诚不欺我
# A15 yyds
# 他是在说赛博瑞克5吗？
# 不是有字幕么
# 手机不要可以给我
# 遥遥领先！
# 遇强则强
# 雷兔兔
# 反向
# 十三香
# 十三香
# 哈哈哈哈
# 懂了，买红米
# 这还是25度用的wifi，用5G的话猜猜多少度
# 有8Gen1内味了
# Intel：坏了，我成替身了
# A16应该是M2的残次品
# 手持13promax续航确实无敌
# 友商远远不及我们
# 安卓躺2年，换苹果躺2年
# 离谱离谱离谱
# 这个aod最没求用
# 14plus成为最大赢家
# 那今年买13不就行了哈哈哈
# 王守义诚不欺我
# 苹果也被制裁了 哈哈
# 还是没对手啊
# 外星科技
# 14Plus会不会是最好的
# [前方高能]
# 续航是可以了，但信号能不能再好点
# 苹果更香了
# 真香
# 买13 promax的香两年  又保值又可靠
# 诺基亚1020 808表示很淦
# 危
# 再过两年就要被骁龙反超了
# +
# 是嘛，我电脑怎么全高200帧啊？
# 别忘了原神现在才720p60帧
# 主要是安卓阵营太拉了。。苹果都不想发力
# 用红魔啊
# 13确实很香
# 5apu那个，法式大长棍！
# 13升ios16不燙了
# 新一代8plus游戏机
# 14香呀
# 看了拆机视频，是铝板
# 叫超速了
# 14plus绝对卖疯
# 8+
# 技术指导：高通公司
# 8100真强
# 多少帧啊
# 简单总结就是挤牙膏
# 都知道，苹果要买单数的处理器
# 懂了买iPad mini6
# 苹果、intel、NV切磋刀法
# 我想到了左脚垫右脚上升，慢慢变成cpu和gpu每两年更替换代，我去这么一想真是到了技术瓶颈了？还是开摆开始慢慢挤牙膏摸鱼了
# 又用5年
# 12系列的外形设计最后的修补 明年应该换外形了吧
# 致敬高通
# 总结，苹果要完了
# iPhone13pro
# 桌面级cpu都是x86架构，和手机的arm架构不能直接对比，同频率的差距那不是一点半点的。。
# 可以考虑外接个3090
# 牌面
# 散热提升了？
# 翻车  等iPhone18吧
# 乔布斯都要气活了
# 14+不得起飞咯啊
# 有种放红魔出来玩
# 召回吧
# 所有博主都没测信号
# 给高通机会了争气啊
# +
# 之前没有怎么重新做
# 因为够用了
# 懂了  13pm 用五年 等终极散热成品
# 懂了 游戏手机
# 挤牙膏。。。
# 要不明年苹果换三星玩玩
# A16：想多了吧？我就是A15+。
# 今年开始接触 同样的价格再怎么说也是买新不买旧吧
# 安卓的中画质连果的低画质都打不过
# 865之于870
# ta很过分了
# 安兔兔不是因为有bug是竖屏跑的吗
# iPhone11 依旧强
# 果子和隔壁高通学坏了
# 妈耶可惜m1跑的是1440p
# 也变得更重了。。。
# 8100中端之神
# 13真TM香啊
# 8100yyds
# 想起来诺基亚了
# 说明全球确实气温在上升
# 王守义诚不欺我
# 我玩游戏都是拿给小风扇对着吹散热
# 真就是王守义十三香了
# 温度凑合
# 等你测了再给
# 可是安卓动辄 5500 大电池或者 200w 快充啊
# 《宾汉流体》
# 看到我的 k50 这表现很满足
# 挤牙膏
# 14PLUS上市直接拉满
# 好家伙，那骁龙888,8gen1算什么
# 王守义诚不欺我
# 有没有一种可能是优化没做好
# 冬天是不是更容易关机了？
# K50U 才是真正的K50 电竞版
# K50U 才是真正的K50 电竞版
# 卧槽，牛逼。比高通还猛
# 《240g》
# 14pro结构跟13一样，散热不好。
# 结构重回复古结构
# k50u无敌
# 怎么没人13香了？知不知道手机更新快阿，新的就是比旧的好
# 总结:8gen2
# 总结:地位不保
# 等折腾了再给一健三郎
# 原神开发者，是用什么手机玩？
# 从东北跑到三亚
# 苹果今年明显不用心了
# 外星科技
# 敢不敢测一测边充边玩
# 世界之巅，有点狂啊。
# 保温
# 手机性能提升原神可以继续往上拉画质
# 他现在的iPhone是向苹果借的，测完要还的，不能拆
# 5c,32位处理器
# 笑死我了
# 手机芯片居然跟电脑差不多
# 牙膏要一点一点挤啊
# iPHone14
# 一见如故：不能说完全相同，只能说看上去，几乎，差不多，一个样
# 好的不学学坏的（）
# 好的好的
# [ohhhhhhhh]
# A14++
# 三秒战神
# iPhone14确定是游戏王了
# 《反 而》
# 三连不是早就给了吗
# 全靠苹果衬托啊
# 还真是十三香
# 骁龙8 跟2一战封神
# 难道提升不是应该的么
# A16测的不对吧，
# 三星
# 上次出现这样的情况还是在上次
# 小何哥哥inflame
# ps5不卡啊？？？
# 频闪怎么样
# 开始挤牙膏
# 20%
# 渲染分辨率一样吗
# 2
# iPhone要是做散热岂不是真无敌了
# intel，这个我熟
# 没落了呀
# 散了个寂寞
# 外星科技，等同行一年
# 老米家为了巩固测试软件地位吧哈哈
# ·
# 高情商：米哈游在激励硬件厂商进步
# 6g运存啊
# 14plus应该可以。
# 挤牙膏
# 不买14
# 再怎么挤，也是领先同行两年
# 石墨贴
# 懂了，14plus最强游戏机
# 外星科技
# 频率性能不一定是线性的
# 十三香
# 暗示挤牙膏
# 《几乎》
# 只要十三不是挖孔屏 就不可能十三香了
# 在销量最高最主流的产品上做实验 您可真棒
# 13钉子户集体噤声
# 感觉如果明年8gen2能耗比更好的花钱，玩原神估计功耗和iphone差不多了
# 果然还是十三香
# 懂了，退了14PM买小米
# 苹果也开始挤牙膏了
# 放心了
# 现在基本不用手机玩游戏，性能完全是过剩的
# 13pro的我不想换机了
# 懂了，这就去买13pro
# 我觉得是a16压根还没研发出来，感觉以后苹果的性能提升会越来越小，所以索性拉长研发周期一代u用两代机
# 原神怎么你了
# 反向升级
# 可以看出苹果的品控很稳啊，两个批次的芯片，体质居然几乎完全一样
# ++
# iPhone14：为发烧而生
# 天机9000牛逼
# 等安卓
# 真就叫超频版。
# a15ti
# 还好我不玩原神
# plus占起来了
# 此时8000+的人在摸鱼。
# 原来如此
# 还记得在iPhone13Pro上面那颗备受好评的A15处理器吗？现在，它来到了iPhone14上面[doge]
# 厂商没优化啊
# 反向升级
# 我8100可以再用3年
# 13再战两年
# 不过分
# 所以m2是挤牙膏
# 娱乐兔
# 十年致敬，没错了
# 高通忍不住笑了
# 5c已经10年了吗 好快
# （13香啊）
# 修复了bug
# 只因了
# 0.
# 红魔不开风扇也不会好多少
# 原神：给硬件厂商加压
# 王守義誠不欺我
# 这提升....换成intel我们一般叫做挤牙膏
# 还没到微不足道的33%
# 主要是能不能稳定60？
# 8g2有机会
# 苹果和高通的双向奔赴
# 高通拉完苹果拉，古人诚不欺我
# 《 反 向 升 级 》
# 因为不努力已经是最强了 那为什么还要努力
# 终于有字幕了
# 乔布斯怕不是要揭棺而起
# 芯片做多了而已
# 完全翻车
# 13pro max 继续每年一换
# 8+有点东西啊
# 红魔7spro更恐怖
# 20年前诺基亚的味道了
# 不断降低功耗，等到电池瓶颈一突破，就可以把所有能力提升上来，毕竟现在提升只能用几小时的话失去手机意义了
# 省电模式下A15性能强16%，功耗多8.7%，这妥妥的退步了呀
# 和安卓关系不大，主要是台积电工艺卡住了，n5p和n4区别不大
# 须弥：你 很 勇 哦~
# 14p年度游戏及预订
# 果吹：
# +
# 《特挑媒体机》
# A16: 官超特挑版A15
# 我将继承和重振PLUS系列荣光！
# 可能就是基带不和soc贴贴了
# 做撒热就得接近300克
# 上班摸鱼
# a15plus
# 半斤啊
# 怕是会有新款macpro要出
# wifi战神
# 钟文泽懂个der
# 没有了，没有奇迹了
# 散热好不等于不发热，外壳温度高说明温度都导出来了。
# 明年见
# 地狱绘图
# 甚至在2k下还缩水了1帧
# 修复了省电模式性能不省电的BUG
# 为什么拿红米测
# 懂了A15+
# 看看高通倒退两年，苹果挤一年牙膏也正常了7
# 13max，换电池，再战一年……
# inter
# 坐等15
# A16的小何同学
# 懂了，买k50ultra
# pc版根本就没优化吧
# Iphone 做散热了，爷清洁
# 但更需要散热的不是pro系列么
# 额菲尔士峰
# 安兔兔因为BUG是竖屏跑分得出来的
# “环保”
# 买个背夹不是提升更大?
# A16开始发光发热了
# 拆啊
# 我已经开始对苹果15开始感兴趣了
# 屏幕的功耗吧
# 钱和三连不能兼得
# 安卓中画质只相当于苹果低画质
# 那应该就是上了均热板了
# 贷款是吧
# 不打游戏 与我无关
# 王守义诚不欺我
# 高情商了属于是
# 红魔直接一条直线
# 安兔兔有段时间麒麟9000l比麒麟9000分数还高，什么成分不用多说了吧
# 每年都有进步就行  晓龙8都多久了
# 特挑体质 降压超频
# it之家打钱
# 8换个a15无敌，seplus
# 14比pro帧率更高功耗更少
#  安卓不降亮度
# 屏幕都快让你按碎了
# A15玩到关服
# 王守义：我就说听我的
# [前方高能]
# 牙膏挤得香啊
# 新牙膏厂
# 膏通看了都摇头
# 王守义yyds
# 1.8万在摸鱼蹲坑
# 可以，5G性能提升
# 等15，可能会有C口
# 骁龙8加这么牛！！
# 王守义13香
# 十三香不是白叫的
# 也比高通好
# 我看到55帧了
# intel直呼内行
# A15超频货
# 价格3倍都不止了
# 13电池有损耗啊，应该说是没变化，没进步，没退步。
# lbw牛逼
# 我更期待8gen2
# 2022年了还烧屏，真就活在过去
# 懂了13香
# 14 plus 22年最香游戏机
# intel：没错，正是在下的独门绝技
# iPhone都有散热了！？
# 懂了，买安卓
# 超频
# 真够明显的哈，第一眼都看不出来
# 库存太多了
# 之前没散热都吊打骁龙，现在加散热之后不得把骁龙打得飞起来
# 散热背夹很重要
# 要睡着了
# 功耗比谁数值高前面的小天才
# 烧屏看亮度的好吧
# 因为A16拉了
# +++++++++++
# 灵魂发问
# A510，这个我熟
# 膏通：你小子学我
# 懂了，因为A16没提升，所以换了灵动岛增加卖点
# 这期怎么回事
# 2.5万人在摸鱼
# 外星科技
# 不过分
# 放兜里会自动息屏不显示
# 怪不得要停产13pro系列
# 还好13pro 没卖  看来没必要换14pro了
# 懂了，14plus预定去咯
# 现在有主流手机跑不到吗？
# 怪不得发布会只提A13
# 你拿14plus和13promax对比散热试试
# 刀法师承黄师傅
# 无散热背夹8g1跑不完
# A系列处理器历史上基本都是单数的版本进步更大
# 没压力
# 库存克星
# 就是超频
# 花了20万？提前开箱
# 感觉14plus的a15会吊打a16
# 主要是安卓这边太拉了
# 单爆500
# 这也算明显进步啊
# 苹果的分辨率没变过啊，提升什么
# 新一代的牙膏王
# 我倒觉得M2就是基于A16的
# 8+连a14都打不过就离谱
# 高通、英特尔：卧槽，它学会了
# 天玑8100杀入了高端机的圈子
# +++++++++++++++++++++++++++++++++++++++++++++++
# 经典次旗舰芯片封神，到哪儿都一样，哈哈
# 12呢
# bug修复了
# 1W
# 《几乎》
# 很遗憾
# 等19，或者m系列上手机
# 一颗永流传
# 没想到，还真是13香
# 那k50至尊其实还是赢了
# 我宁愿多个几十克，换更多的续航
# 懂了买15
# 1.6万人
# 危
# 14plus等10月了
# 13pm都过去一年了，电池也会损耗，这差距当误差都可以
# 害，还以为没了
# 超速了
# a13比8+强是真的
# a15外星科技
# 十三香
# lpddr内存即使多了用不到也不耗电
# 妥妥用一年
# 苹果13的图片是背面，苹果14是正面，有猫腻
# 英特尔:专业啊
# 13pro躺赢
# 会烧屏嘛
# 8gen2锤爆之
# 都120了还测60。。。。
# 有没有可能A16是不是残血版
# 哈喽  大家
# 手持12不买的飘过，看明年15有没买的欲望
# 更费电
# 世界名画
# 不装了，我摊牌了
# 等到你了
# 差不多啊
# 低情商：完全没变化
# 明年见
# 这个灵动岛估计又得用十年了
# 几纳米和物理大小已经没关系了
# 13香啊
# m3必定要上n3的架构会大改
# 笑死 怕是用一年电池损耗的差距
# 但4000多整个跑满中画质有的怨种
# 今年A16存在感感觉有点低
# 正片开始
# 我麒麟呢
# 没高刷
# a15一代神
# iPhone13.5
# 所以 a15 a16差不多
# 苹果：别急感觉高通太慢了而已
# 那不得谢谢火龙这波原地踏步附送徒增功耗。果子厂：哎~摆了
# a15plus
# mini6散热也一般
# 挤牙膏
# +
# 王守义诚不欺我
# 原神3.0直接寄了，你以为像之前的呢？
# 888行为
# 懂了，选a15
# 就提了一下
# 手持iPhone13
# 感觉不如澎湃
# 苹果还担心烧屏？安全得很好吧
# 基带更新？
# 《差不多》
# genshinwan 堂堂登场
# 按端游做是指ps5都卡么？
# 明年高通至少GPU可以超车了
# a15ti
# 高情商：转移重心  低情商：开摆
# 等等...好像没有mate40
# 懂了，下一代A17在这个地方比A16提升16%doge
# 我就想知道信号怎么样
# 8plus真的yyds
# 竟然有飞友？
# 手累不累
# 十三香
# 十三香
# 十三香
# 明显进步  外星科技
# 答案是红魔，yes
# 厨子挤牙膏石锤
# 牙膏厂的孪生兄弟
# 没意义，大小差太多了
# 几乎征服了元神
# 危
# 懂了，a15是瑞龙5000系列
# 牙膏厂 A16啊
# 有二手手机销售吗？
# 难道库克也知道王守义吗
# 十三香
# 8100的能耗比瞩目
# 可能要做游戏手机了
# 讲一下高通骁龙8Gen2芯片？
# 安卓要用苹果这散热直接爆炸
# 专业
# M1准备上手机
# Intel直呼内行
# A16替身了
# 懂了 等15
# a14++
# 连M1都稳不住60帧了
# 看拆机找微机分楼斌啊
# hhhhhhh
# 反向升级
# 更拉了
# Ios有像素点位移的策略，小白条都没多少人烧屏
# 右上角那台烧屏了吧
# A15Ti
# 绷不住了
# 哈哈哈哈 甚至不挤牙膏 直接躺平
# 牙膏厂实锤
# 换了高通基带
# A15s
# 还是得MINI6
# 60hz游戏手机，哈哈，苹果粉玩王者要不要试一试120hz？？？？
# 必须给
# 元神:苹果没充钱
# 3a大作
# 有钱就买新款啊
# 笑死我了
# 中间夹散热材料的小天才 您这散热材料是辐射散热的嘛
# 散 热 背 夹
# 反 向 升 级
# “安卓旗舰”2999”
# 苹果没有忘记初心，强调自己是个电脑公司
# 降低的功率为m2最低功耗的1.8倍
# 竟然知道ROB test？？？专业
# 挤牙膏
# 米哈游：就你？小别扇
# 没有提升
# firestorm永流传了
# 15.2没有问题啊，设备型号
# 看看隔壁安卓的功耗
# 知道买哪个手机了吧
# 高通 学我是吧
# 还好我不玩儿原神
# 挤牙膏了
# 挤牙膏
# 今年性能挤牙膏所以改散热
# 牙膏实锤了
# 苹果是实在想不到有啥好改进的了，
# 前方高能来了
# plus成游戏机了
# 真就两个8100单核等于a16单核
# 温馨提示，上世代跑分软件是崩坏三
# 牙膏厂的味道
# 挤牙膏
# 有请我们的红魔7Pro的选手上台
# b站弹幕现在太潮啦
# 这么一看14plus要无敌啊……
# 等8gen2
# 别说烧屏美滋滋，直接换新哈哈
# +++++++++++++++++++++++++++++++++++++++++3
# 都不敢用原神演示散热
# 手拿11 等16
# 有没有可能是用了一年 iPhone13电池有损耗？
# 玩游戏还是红魔吧
# 红魔7sPro呢？可以稳定60帧
# 红魔7sPro呢？可以稳定60帧
# 等iPhone19
# 13pro香
# 哈哈哈哈哈，还吹不吹了
# 8plus用了5年了
# 而k50ultra价格只有14Pro的一半！
# 牙膏实锤了
# 给，必须给
# 十三香
# 等A17
# 绑头带
# 可惜没高刷
# plus十月份才发售啊，出两个视频有问题？
# 王守义说得对
# 《致敬英特尔》
# 都还没测呢，是真的很过分
# 这样子明年高通的A卡就要追上了，真的好吗
# 外星科技
# 挤牙膏
# 不装了 我摊牌了
# 挤牙膏
# 888和865直呼内行
# 等8+Gen2了
# 13pro max钉子户拿定了
# 灵动岛就是未来iPhone三五年的模组。不用想
# 全体起立
# 吊打安卓
# 13系列集体沉默~~？
# A16:我们进行了一点优化
# 年度游戏机
# 苹果有景深
# 这边压力给到红米1999
# 13香啊
# A15 pls
# 14没高刷 13破还是香
# 把控的很好
# 高通追不上，很难讲哦，毕竟接下来马上就要发布新款高通处理器了
# 真A15+
# A15比A161440P强一帧
# 懂了。买14
# 王守义：我就说13香吧，有高刷游戏强
# 不如加散热背夹
# 这是个区别是因为天上上云位置不同，所以地上阴影的位置也不同
# 草 分数都一样
# 没高刷的游戏手机可太扯了
# 连高性能主机都能卡单纯的证明他没有优化
# 安卓不便宜你苹果便宜是吧
# 懂了 买15
# 13promax香
# 十三香
# 说明拉了
# 保留节目
# Intel:你们干嘛都看着我
# 强行说通
# 懂了买iPhone 13
# 略略略
# 懂了13pro max成为钉子户了
# 居然不是云飞
# 功耗降低20%
# 真的开始省电了
# 懂了买13Pro
# 电脑打游戏不想吗
# 我很强
# 懂了上iQOO
# 他真的有在认真做成一个跑分软件
# A15yyds
# 有没有可能是优化问题
# iPhone13s
# ？？手持ps5不怎么卡
# 一千多的台式都不卡。。
# 13pro路过
# k50这么猛？？？
# 明年见
# 红米k50不服！
# 骨瘦如柴
# 挤牙膏
# woc？
# 2
# 正在用苹果看视频，烫爪子
# 谢谢 明白了
# k50牛啤
# 14plus游戏机实锤
# A15用5年不成问题
# 散热就不是苹果了喂
# 高通衬托罢了
# 十三香
# 什么13，14，15，16的，乱蒙圈了
# 所以这点功耗尊贵的苹果用户会在意吗
# 所以这点功耗尊贵的苹果用户会在意吗
# 14比13香太多了
# 懂了，14Plus游戏王
# 台积电牛逼
# 运存多大？
# 欧文？
# 看左下角啊
# AOD会烧屏吗？
# 原来8+这么厉害吗，那我直接mate50了
# 跟红魔比都是弟弟中的弟弟
# 13香
# 是不是没有优化
# 会不会用在刨丝器上呢?
# 笑死我了
# iPhone13s
# 不出意外的话。一样发热降频，屏幕变暗。不信夏天见。
# 14没高刷，知道买啥了吧
# 13Pro真香
# 说明14才是走量只有14才做了散热？
# 懂了买13pm
# a15max
# 我愿称之为A15+
# 懂了 苹果想把M处理器放到手机上（
# “60帧”
# 7000+
# 红魔无敌了
# 挤牙膏
# Intel：这个我懂
# 8100    666
# 就是体质变好了而已
# 对不起我等15
# 原神封神了
# 期待8g2
# 米忽悠：等以后你们“征服”了原神我再开个1080p120帧玩玩
# 但14plus没高刷
# 原神与时俱进啊
# 怎么走，都是向下
# 刚把13pm卖了
# A17: zenith（苍穹之顶）
# ps5确实卡
# A16，我可以等iPhone15或者se5
# 14被叼打了……
# 苹果鸡贼后面发布，不然都去买14+了
# 《田忌赛马》
# 挤牙膏
# 充电再快一些吧
# 散热背夹需要使用散热背夹来散热吗？
# iphone 6系列
# 重点：进度条没过半
# A15一帧秒杀
# 外星科技
# 0.5whhh
# 我不理解为什么有14
# 买了14
# 是信号
# 82222222/
# 相当于以后M下放到手机？
# 最没用的功能了
# 看了看进度条，还有，不用担心，还以为要分两期
# iPhone14proMax 重量：240g！！！！！
# 高达0.3W
# 退了，等15
# 而且安卓电池大
# 息了个寂寞
# 云飞哪里去了
# rtx3080ti+5950x表示不服，
# 、
# 现在用的机器应该是媒体机，可能要还回去
# 我还是觉得安卓这种更好
# -
# 未来1纳米岂不是飞天了
# mini6的胜利
# 游戏发烧友用手机打游戏？？？
# 这下14和14pro基本没差了 合理
# 8g+也还不错啊
# 优化LJ罢了……不能怪cpu，电脑上3060一样卡
# 新芯片还没优化 这还不知道嘛？？？？
# ..2
# 《iphone15.2》
# 13香还是13香
# 因为GPU没啥提升，哈哈
# a15plus
# 超频是吧
# 挤牙膏
# 没错，就是“略高”
# 懂了不买苹果
# 明年换架构，然后又砍掉散热？
# 王者120帧只在iPad Pro上适配
# 不热就不会散
# 14标准版省不省电都一样捏
# 外星科技
# 还好我的电脑性能够，只是负载也高了一些
# ipad mini yyds
# 不能说很像只能说完全一样
# 骁龙8+连A14都打不过吗
# zen3-zen4
# 1.2万加人在观看
# 不过分
# 买13
# 为了ultra机型让步
# 答：什么都没有
# AOD一开就露馅了
# 直接就拉了
# yyds，厉害哦
# rx6700xt表示不服。
# 怎么不把红魔放出来
# 红魔一个能打的都没有
# 看了酷安，我tm以为8+真赶上来了呢
# IT之家牌面
# 三秒降亮度的手机，只能用WiFi玩的手机搁这谈玩游戏
# 怕不是15也要继续用a16了
# 懂了，要把M1塞手机里
# 3090不卡
# 13PM无敌
# 终于知道为啥苹果要拿a13比了  因为友商最顶的cpu还不如a14
# 感受的话基本没啥差别
# 首席头牌
# 明显....
# 这不就是正常的迭代周期，一年架构一年制程
# 因为苹果就那么几款手机，安卓千奇百怪不好优化
# 万万没想到这个视频会提到6s
# 14p打游戏岂不是很舒服
# 苹果的腿更精细
# 在未来,16x有望成为M3处理器
# 年年换新走起
# a15plus
# 十三香
# 你确定有A16芯片
# 那看来我的13Pro银色顶配版非常香
# 低情商：优化差
# 保留节目
# 比15还拉，真就风水轮流转
# 库存
# 带不动 原神nb
# 啊。。。。。这。。。。。
# 全体起立
# 14高刷都没
# 马上被14plus超越
# 一颗永流传
# A15+
# 等楼斌的拆机
# 就等你了，哥
# 地狱图
# 王守义 13香
# 14plus，yyds
# 拉了 被8gen2爆杀 8gen2gpu比8gen1规模提升百分之五十
# iPhone13.5
# 甚至低了一分！
# 13香
# 8000人在摸鱼
# 再也用不上便宜美版iPhone了
# 14 PLUS才是年度游戏机
# 高通要翻身了
# A710 A510直呼内行
# 老黄：这刀法可以啊，但要和我比还差点
# A710 A510直呼内行
# 极致画质120帧呢
# 相比安卓现状，苹果不需要进步了
# a15甚至高一分
# 主要友商不给力，苹果只能慢慢挤牙膏。
# 晓龙争点气啊
# A15是真的省电又强大
# 下一代没准就是M1手机
# 10年才能进步百分之百
# 13馫
# 牙膏厂真传
# 只因PU
# 散热怎么改善，需要改善低功耗减少发热就行
# 你电池小
# 王守义：13香
# 没有散热重做还是没有啊
# 散热背夹，那没事了
# 这里好像是山西啊
# 香香
# 考研休息区
# 上原神
# 牙膏厂都挤得比它多
# iPHone看起来好怪。。。。
# 手持mini6
# 还是13香
# 这啥？《太空哈利》？
# 期待8gen2
# 8 plus可以换14 plus了
# 重做的前提是以前有吧？？？
# 反正我不玩游戏
# 买16 iphone隔三代
# 我有个问题，用13pm，14啥的人都没有电脑吗？
# 反向提升
# 早就有均热板了大哥，前几代苹果就有均热板
# 还没优化好
# 还好我不玩原神
# 就是调整了内部堆叠，根本没上散热材料
# 王守义14香
# 明明是安卓吊打好么
# 8gen2可以反超了
# 懂了，买8100
# 高通:抄作业是吧
# 别忘了还有14plus
# 13香
# 难道不是应该用14promax测试吗
# 怕不是在偷偷挖矿
# 库克故意的吧
# 麒麟990和麒麟9005g的变化
# 真的买13够了
# 过分！不给
# 最好不要提高，不然我A15还怎么混
# 怎么不测充电  一测苹果就不测充电了？？？
# 省流：a15依旧很强，a16挤牙膏。总结：外星科技
# 测下充电撒
# plus别做梦了，比max电池还小一点
# 骁龙8+这么猛
# 挤牙膏实锤
# 安卓200w充电和5000毫安电池
# 那就是说iPhone 14 是没有灵动岛手机的巅峰
# 有算法优化的，不会烧屏
# 苹果1
# 还真的是13香
# 果然还是13香
# 像iphone4
# …………
# 雀氏ps5掉帧严重
# 321
# 试试5g下
# 十三香
# gpu苹果可不比高通强太多
# 可是14连高刷都没
# 还好我不玩原神
# 我记得评论区还有个人吹14pro散热玩半小时原神最高38度的
# 暗示苹果也开始牙膏了
# 苹果：不然呢，你猜我为什么不说
# 次时代唯一指定跑分软件
# 散热好了，处理器不降频一直发力，功耗当然高，这才证明有散热好吧
# 小米这个8g1是比较差的那个
# 十三香
# A15 &gt; A16
# 这里明明都是6.1寸的机型，哪里不一样了
# 之家排面
# 乌兹不压30刀就是被压啊
# 牙膏挤爆了
# Apple：很强？那我更新一下系统就好了
# 为什么不是酱爆在讲
# 这张表的亮点在8100了
# 库存
# 控制变量测极限性能啊
# 真略微
# 惠！
# 懂了，买K50
# 13pm香香香
# 王守义说对了，13确实是香
# 说iPhone AOD烧屏的是真的幽默
# 亮度不大没事的
# 直接2.5万
# 危
# i3
# 那是被镜头限制，镜头那么大怎么给大电池？？
# 14普通版是60hz屏幕，确定能当游戏机？
# 挤牙膏挤成这样
# 因为今年挤了牙膏
# 懂了，买13proMax，香
# 大嘴：遥遥领先！
# 跟我没关系，手机不玩大型游戏
# 十三香
# 单从性来看，13pro系列没必要换了
# 已经不是牙膏了 就是创新包装了一下
# Everest
# 小荷
# 不买了，，这太拉了
# 我买了IP12，等华为
# 无敌（字面意思）
# 这个调度才是最正确的，省电模式就应该降大核超小核
# 外星科技
# 有没有可能，iOS16米憨游还没优化
# gpu几乎没提升
# 苹果现在再想提升要靠台积电了
# ha
# A15+
# 14pm和14plus电池几乎一样，但是苹果宣传14plus是苹果续航最好的手机，a16省电在哪？
# A15省电模式＝游戏模式，A16省电模式就是省电模式
# 能效比没8100高
# 13香，王守义没说错
# 牙膏  环保
# 有没有可能是 原神没有对新机型适配优化的问题？
# 看来苹果在基带上投入的研发不是完全没有成效的
# 苹果换流量玩打不过安卓普通旗舰，wife干不过安卓的游戏机
# 怎么还没哟字幕就发出来了
# 这样的息屏显示简直是本末倒置
# 这还只是14，14plus可能会更好一些
# 懂了入13pm
# 过份
# 导到金属边框，靠边框均热
# 说了25度，300亮度
# 卧槽，降维打击
# 拉满的14pm呢
# 散热？为AR铺路
# 不打游戏那还是13pro香啊
# pro都有这么好
# 懂了，等15pro
# A13和A12不要藏起来嘛
# 蓝厂做法
# 还没开省电模式
# 前面不写着5G环境吗
# 散热背夹，地狱模式呢
# 错，iPhone15也会用A16
# 高情商：英特尔桌面级性能升级
# 超频
# 这个药丸我真的绷不住了哈哈哈
# 米哈游：还跟我要1080p吗？
# 两边差不多嘛
# 测试误差吧
# 刀法
# 丢龙了
# 有点进步 但不多
# 苹果还是强啊
# 看起来天玑9000性能不错啊
# 危
# 明年见
# 危
# 明明是个手机游戏优化又不整好
# 我先来，外星科技A16
# 8gen1真牛
# 小荷才露尖尖角，功耗也要节节高
# 我的云飞呢
# 王守义13香
# 1
# 甚至还低了1帧
# 这个结论咋得出来的
# A510是吧
# 高情商
# 没高刷
# 这才是正常使用环境，谁没事天天玩原神
# 功耗高还好?
# 版本问题吧？
# 销量也是iPhone5C
# ‘\
# A15TI
# iPhone14=iPhone se3(doge
# 草，退货
# 不，13还是香
# A15 Ti
# hhhhhhhhhhhhhhhhhhhhhhhh
# 前方难绷
# 所以为什么要有小核直接中大不就行了
# 吊打骁龙8Gen1+
# 13香
# A15 GEN1
# 13 香
# PS5配不上原神
# aod还是会烧屏的
# 13香
# 那个省电模式会锁60的，我平时都不开，说看不出来的根本就是没看过
# 13香
# 反向pro
# 14plus 新一代游戏机
# @XIaoMi
# 怎么都跑不过a15啊 安卓
# PS 和 PR
# 省流：牙膏都懒得挤了
# 66666
# 略若
# 13香啊
# 买14plus
# 3070ti：真的能不能给点压力
# 低情商：挤牙膏
# 别忘了P系列刷新率是自适应的，你固定60刷新不一定比高刷省电
# 烧屏的应该都没用过apple watch吧
# 13p沉默了
# 热知识：外边越热反而代表散热能力越强
# 远 峰 蓝
# 2999和7999不是便宜是什么
# 十三香
# 1
# 等15就对了
# 烧屏又费电，熄屏来相见
# 英特尔:你就玩玩我剩下
# 不如某个7spro啊
# 进步了3分钟
# 预计iPhone16直接上M1
# 14plus更好？
# 还是13香
# 可是其他人连替身都打不过啊
# 其实都差不多
# 落后两代
# 13香
# 懂了，等iphone15
# WiFi战神名不虚传
# 笑死，小一万的手机不能玩游戏是吧
# 省流：不值得换
# 吸牙膏是吧
# 俗称挤牙膏
# quanrtiqili
# 安卓早就有了
# 火龙888复刻？
# 总结：超频
# 我绰，天玑能耗这么低
# 宝马m3是吧
# 太失望了我跳
# 知道买哪台手机了吧
# 5c外观起码重新设计过，14有啥设计啊
# 省流：本代为挤牙膏
# 、
# 不怕烧屏吗
# 刷60帧的测原神 安卓都能跑120帧是吧？
# 请购买promax
# 等明年
# 有请原神
# 反向升级？
# 苹果一开数据就GG
# 为什么我的k50Pro只有4000
# 还是13香
# 13香！
# 1
# 懂了  等15
# 笑死我了
# 我笑了，晓龙直呼内行
# 不用散热背夹肯定降频，功率不稳的
# 13香
# 就是加了个铝板隔层。
# 挺好的，处理器真的很强了，没必要老提高
# 高情商:有提升 低情商:挤牙膏
# 发哥跑分这么厉害
# 省钱了，13pm看来还可以再战到15出来
# 懂了，不玩原神
# 那是功耗啊8+功耗那么高
# 但是14没有高刷吧
# 这续航真无敌啊
# 为什么是你来播
# 牙膏厂今年13代终极小牙膏
# 全tm是致敬.jpg
# A15Z
# 快拿出我的k50
# 我敲，太失望了
# 牙膏盒子都没开
# 左边三星
# A15牛逼
# 感恩 13p笑了
# 13有灵动岛？别酸了。。。。。
# 骁龙努努力 给苹果点危机感
# 全程5g续航非常不错
# 大精灵泉。。。。。
# 反向pro
# 没有对手 自己随便玩玩都是第一
# Minecraft+超清材质：看不起我吗？
# 专业
# 七千多 连个高刷都不给
# 正片开始
# 14plus才是yyds
# iPhone12也很放心
# 被安卓秒杀
# 8100牛逼啊
# 非常关心就是散热
# 苹果手机性能跑分没输过，游戏体验没赢过
# 不是九年？
# 就是纯纯没优化
# 测一下华为mate 50的功耗
# 说苹果散热不如看看小米
# 反向提升
# 我电脑cpu才3.3ghz
# 3000+
# 地     狱     绘     图
# A16=A15+
# rx588
# 王守义诚不欺我
# 库存
# 这是个区别是因为天上上云位置不同，所以地上阴影的位置也不同
# 全世界都在等麒麟
# 安卓：我有k50
# n4能效本来就不如n5p
# 懂了，等8G2
# 是真的烫没玩了
# 13香
# 14plus呢
# PPT动画做的不错
# 原神就纯纯是电脑游戏
# 13香
# 懂了 马上退货 继续用13pm
# PS5须弥掉帧严重 蒙德树多的地方就有掉帧
# 但是买个散热背夹就全部解决了，不想看药丸还是刘海更好，13PMYYDS
# 功耗降低20%
# 那就对了
# 苹果人家就叫这个“始终显示”
# 13pm香
# 前面的和电脑比没意义啊
# 苹果终于堆散热啊还行
# 就是说苹果到头了
# 你觉得待机息屏显示花的电会比这个连续8小时的日常循环耗电？这个都没问题你还担心待机AOD干嘛？根本不用测
# 懂了13p加背甲
# 我急了，烧屏烧屏烧屏烧屏烧屏警告
# 14plus能封神吧。毕竟面积大了
# 因为没卖点了 提升一下
# 但你在同样的APP跑   赛道是一样的
# 20%？
# 背刺失败
# 好家伙倒吸牙膏第一次见
# 烧屏说白了是寿命差异，亮度这么低对寿命损耗很小
# 13香
# 指导人：黄仁勋
# 13pro发热很大
# 爱你孤身走暗巷
# 基带升级了
# 丝毫无提
# 牙膏
# 怎么还少了一帧
# 14中间多了个金属片隔断
# 隔壁骁龙8+都不敢说这么多
# A16就是个15的牙膏
# 库存吧
# 炸出来一群飞友
# 真就十三香呗
# 别测了 再测移动端就玩不起了
# 14内存6g起 还是有点心动
# 烧不了，watch三年多了都没事
# 买手机的基本都不会看这种测评
# 内存有什么用  我不玩大型游戏
# 高情商:一见如故 低情商:完全一样
# 苹果又不是游戏手机，又不是人人都买散热背夹
# 13香
# 那确确实实就是最高峰
# A15 gen1
# 这才最重要 不可能天天在家玩游戏 室外场景多
# A15+
# 你在30读环境开高画质打原神？这叫实际使用？？？
# 苹果向来都是一代改外观一代换CPU架构，14 pro算是变了外观（药丸），所以CPU没提升是正常的。明年的15才是s的精神传承
# 原神太小儿科了，只有switch模拟器才能榨干性能，测出真相
# 要记得重量 尺寸 还有充电速度呦
# 合理，因为他没说史上最强gpu
# 就这种画面都能卡。。。也是牛掰了
# 改散热可能是为了以后直接M系列阉割塞手机
# 全体起立
# 掉帧森林
# 水果味牙膏
# 不会烧屏的，看aw就知道了，这么多年了也没看到谁说aw有烧屏的
# 、
# 总结：等15就完事了
# 买14plus 游戏神机
# 865870
# 懂了，以后iPhone要用M系列处理器(doge)
# 有没有可能 ios就没有给120帧
# 因为AOD
# Qomolangma
# 王守义说的没错，还是十三香
# IT之家好评
# 14没啥诚意
# A15+
# 优化确实拉
# 8g2
# 散热不一样
# 难绷
# 13香
# 有高刷一切好说，但是没有
# 挤牙膏都在前排，没办法，太强总是造人嫉妒恨啊
# 苹果8gen1
# 但是14plus没有3dtouch 而且还是60hz 说不定还是双层主板
# 方向正确
# 13香
# 改了内部设计
# 14挤继续牙膏，15上快充
# 8100这么猛吗
# 13香
# 给8gen2机会了
# 、
# M3边角料
# 前面说13香的还在吗？
# 懂了，这就把14Pro退了
# 有骁龙888内味了
# 5C我的第一台
# 左下角一块散热背夹（笑）不过理论最佳性能吗，你冬天跑的到吧
# 我还以为从5800h到6800h
# 夭寿啦！苹果做散热了，不是处理器压不住，那就是吊着安卓处理器打
# 翻倍的性能，换能耗转了
# 石墨贴
# Core A15
# Tik-Tok模式在苹果也得到了体现
# 懂了不玩原神
# 13香
# 去野外啊在城里有啥嘛
# 高情商
# 高情商：蓝厂6代到7代；低情商：挤牙膏
# 小米12s
# 价格差的功耗可以无视
# 遥遥领先
# 从沈阳大街跑到理塘
# 13p也有promotion
# 高通什么时候追上苹果
# GPU完全没提升。。。
# 苹果飘了
# 今年A16牙膏都懒得挤了是吧
# 不是高亮度一般不会烧，现在OLED挺好的
# 手持13观看
# 对不起，这两个币我要省下来买华为
# 十三香
# 隔了7代了，我可以下手吗
# 乔布斯如果不是胰腺癌，放在现在可能是被厨子气死的
# 三星这个续航要命啊，能有5小时吗
# 13pro直接下架了给你
# 13香
# 没有提升，还是第一
# 没对手，难道还要我左手打右手么？
# 0.5W叫改进
# 13pro一代钉子户！
# 苹果不落下风就是胜利
# 体验是真的拉
# 推土机直呼内行
# A15+
# 66666666
# 铠皇铠爹
# 拿安卓中画质来BB的是不是搞笑啊，人家苹果中画质比安卓高画质还高
# 这摄像头看着好出戏
# 省流:請去買I13
# 14不是还有个plus机型么，那个估计挺能玩的
# 怪不得第一时间下架13p系列
# 《反  复  强  调》
# 说不烧屏的哪来的勇气
# 测试机貌似要还回去给苹果的
# 甚至还吸回去了一点
# iPhone ； 都散了吧
# 经典参数没输过 游戏没赢过安卓
# 就是优化差 就这画质 ps5还会卡
# 1
# 8G1跟8G1+是同代的，但三星跟台积电可差不知几代去了
# 有没有可能还没有优化？？
# 华为不卡
# 低情商：优化差
# 略
# 又挤牙膏 ?
# 4800w像素的画面曝光和颜色饱和度没1200w像素强，官网提了
# 高情商
# 石墨贴，老外拆机了
# 真就叫稍微。
# 屏幕120hz都没有，还游戏手机呢，笑死了
# 远程施法？
# 14plus不得起飞咯
# 全体起立
# k50 牛逼
# 俄罗斯买得到吗
# 7000＋的人在摸鱼
# A16堪比以前的A10了，性能挤牙膏
# 安卓小核都不挤
# 13香
# 拿个mini6对比下
# iphone杀手
# 13香！
# 应该是还没做好适配
# 不玩原神的毫無壓力
# 库存
# 这功耗是怎么测试的
# 567牙膏王
# 1
# 明显带着偏见的 不科学
# 云飞呢，我要听他说
# 别吹省电模式了
# 王守义 13香
# 好消息，好消息，苹果a16没挤牙膏
# 我杀我自己
# a16只因
# 一看到5g就有点不忍心往下看了
# 怎么不拿14Pro
# 全体起立
# 13香
# M2上面切下来的
# 1
# 懂了，13继续战斗买17pro
# 13香
# 13香
# 别忘了单核
# 三连不是药丸么？
# 8+这么厉害的吗
# 13馫
# 不成熟@
# 888低负载下能耗也不错
# 怎么不是云飞
# 这个品牌确实没法用暗号
# 74.6&gt;77.2
# a15=865
# 均用散热背夹，看不见小字吗？
# 安卓便宜？？？？
# ....
# 13香
# 看左下角小字
# 前面得画质介绍这么快就忘了，果然某些安卓粉都是不长恼子的
# 一技能没好 就狂点？
# WiFi战士
# A16:糟了，我成替身了
# 14Pro咋还有个横屏home条啊
# 高情商
# 这回14Plus是赢家了
# 14 plus YYDS
# 13香
# 元神苹果定律
# 才哪儿到哪儿 就给三连？ 不给！  给了。。。。。
# 拿ipad mini6还是很舒服的
# 高刷不下放就不买
# 别的都看个乐，真跑分还的看雷兔兔
# 还是13香
# 还是13香，性价比也高
# 库克切有底气啊，后面的人连A15都没追上呢
# a16就是为4800像素准备的算力，不是让你玩原神的
# 你能想到烧屏苹果想不到是吧？
# 这可是全程5G，如果全程Wi-Fi更封神
# 苹果高情商，等你安卓阵营一年
# 但是没高刷
# 一个三千，一个八千
# 妥妥的游戏机
# 电脑处理器
# 等15
# x65基带吧
# 8100能耗比接近a15了
# 1080分辨率？
# 说实话，如果你不是科技圈，发烧友，13PM确实比14PM香，毕竟灵动岛的热度一过，13PM会更香
# 懂了，买14plus
# 5apu幻听
# 13香
# 不管你配置有多高，总有办法把你配置吃满
# 懂了，买14不买pro
# 13又是一代钉子户神机
# 都开始牙膏都开始牙膏
# 我早就说了，14plus会是王炸
# 没活了可以咬打火机
# 没变化
# k50 2000块钱都成旗舰了嘛
# 13香
# 13香
# 8100是不是看错了比8G1还高
# 1W也还不错
# 月销0
# 关键是便宜
# 生不逢时啊 非要在iPhone14发布那年高考……
# 性能打七折
# 牙膏倒吸了属于是
# 说屏幕的14Pro和14不是一样大小的一样分辨率？
#  LED会烧屏吗？
# 英特尔哈哈
# 问题是谁天天拿手机打游戏啊。。买个pad不香吗
# 我要买猪王家的午餐肉
# 低情商：没进步
# gpu没变
# 明显没啥提升
# 说红魔的多少会买呢
# 安卓阵营太不能打了
# 60。。。。
# 15岂不是香爆了
# 反向pro
# 14pm一万元
# 略强0.2帧，暴打老旗舰
# 新？
# 不是，这个骁龙是假的吧！我
# 13香了
# 感觉不如865，99的稳定度
# 不如液氮降温
# 这不比安卓8+机型还热啊？
# 但是没有高刷
# 等iphone100好了 直接机械飞升
# mhy：我们征服了A15
# 牙膏被锁起来了
# 红魔7pro干爆
# 拆开看看
# 怎么不测红魔dogedoge
# s系列可没用过前代soc，应该叫iPhone 13c
# 热知识：苹果称14plus是续航最好的机器。但是14plus电池和14pm只有几毫安时的电池差距，基本一样
# 细节空兵
# plus新一代游戏机，8p可以换了
# 泯然众人矣
# 拉拉拉拉拉
# 红魔7s pro应该可以
# 懂了，买14plus，继8p以来的又一部游戏神机
# tiltok策略
# 库克：就你能，就你知道。
# 安卓都是90+
# -1
# 8100外星科技
# 不玩原神不就行
# 14普通没120肉眼可见的嫌弃
# A14.5
# “调不好不发布”
# 色彩有差异啊，iphone是低色域吗？
# 看主持人就知道了这次14拉不拉
# 不过分
# 手机性能基本过剩 在往pc方向发展
# 懂了，我马上就退
# 比起安卓散热还差太多
# 等8g2出来就被超了
# 不把红魔7spro拉出来玩一下？
# 王者不应该120帧吗
# 这不拆机看看到底有没有散热
# 开极低卡估计是处理器偷懒了
# 温度呢
# 红魔：就这？
# 零洞岛doge
# 很遗憾
# 库存华容道
# 库存没清完可以理解
# 11呆酷睿直呼内行
# 去库存而已
# 11月份的8gen2要反超a16了
# 飞不起来的5APU
# 误差范围内
# 吃了咖喱
# 手机利润是pc的多少倍，试验田？太强行解读了
# 他甚至不如a15
# 《功耗比上一代降低20%》
# 不能说一模一样，只能说完全相同
# 这么看A14厉害啊
# nice
# nice
# 红魔7spro申请出战
# 8.1
# 说降温的，难度不知道这些实验都是控制室温的？？？
# 听说有vc
# 拿安卓中端机对比 9月发布的苹果？
# 13标准
# 懂了，马上退了明天到货的14pm
# 省电模式策略更激进了，为了续航吧
# 遥遥领先
# 绷不住了
# promax呢，机身更大，散热更好
# a15+
# 这应该是基带更新带来的提升
# A15-
# 44.6
# 13系列用户又是一代钉子户了
# 13香
# iPhone13PM笑嘻了
# 买14plus真不如买13pm...
# 13香
# 懂了等17
# 直接等m1手机
# 温度比安卓还高
# 一块砖
# 天玑牛逼
# 怪不得13香
# 做散热就说明开始挤牙膏了
# 带个壳都一样
# 遥遥领先
# 还不!盘..
# 苹果：给你们一年时间努力
# 高通：我tm来辣
# 懂了  买14 P
# 13香了
# 算是翻车么
# 手表aod已经三年了吧，问题不大
# 真省电了
# 上高配原神！
# 钉子户来了
# a15大翻车
# 懂了：比A15略高
# 1万多人上班摸鱼。
# 小米12SU重量多重：225g
# 建议室外三十度5g试试（）
# 什么若只优化
# A16
# 准确来说10年翻一倍
# 高情商
# 内部结构倒置，散热必须行啊
# 承认这回拉了就这么难吗？
# 被k50u吊打全系还行
# 红魔不吊打果子
# 天玑9000这么猛？
# 没差别啊
# 啥时候搞个代号：马里亚纳
# 本来就是PC游戏
# 其实iPhone真正续航不好的帽子是在11那一代摆脱的
# A16Z
# A15plus
# 笑死了这一段对线
# A15这芯片确实不错
# 笑死
# 人口分界线是吧
# 额erest
# 苹果六核比安卓八核都强
# 高情商
# 就是换个名字降个级吧
# 牙   膏   倒   吸
# 14p就差个120hz和长焦就能起飞
# 田忌赛马
# 给力
# 我不要高刷我就要续航，plus香！
# 苹果马上就有了
# 那些吹充电功率的出来说两句
# 库克给你远程施法让你强
# 说13香的注意，14全系6G运存哦
# 苹果帧率不行那一定是游戏优化不行
# 自适应刷新又不是万能，电池少了200毫安还多那么多耗电的硬件肯定打不过标准版了
# 因特尔
# 压力给到了骁龙的GPU
# 价格好几倍 怎么不说呢
# 苹果1年没刷牙
# 8p也没有高刷，不是还有很多人当游戏机
# 4不就是5plus
# 讲一下高通骁龙8Gen2芯片？
# 讲一下高通骁龙8Gen2芯片？
# 讲一下高通骁龙8Gen2芯片？
# 讲一下高通骁龙8Gen2芯片？
# 不带安卓玩吗
# 并不能
# 苹果是不是要搞超算？
# M1一切二拿到手机上用，统一CPU，一会A系列可以不用研发。省了多少钱。
# 这还是1w的机器
# 13香
# a15+
# 云飞呢云飞呢
# 14plus要封神了
# 我感觉早就该这么干了
# 等华为mate
# 塔塔开，别问几几开了
# A15+gen1
# 并没有 promotion可以最低10hz运行
# iPhone：你是故意找茬是不是
# 上一个寄成这样的还是iPhone7吧
# 甚至1440P还低了一帧
# 13p值得
# 确实是正代plus啊！
# 跟牙膏厂一样了
# 是和a13比的
# 友商不争气啊
# 牙膏成精
# 噗。。。这就是惊喜吗？
# 烧个啥..那么低的亮度..
# 都说了带p的高频优势就在这，即使是现在也是n5p比n4还贵
# 高频带p的优势来了
# 55555要走888老路吗
# 有5G那4G呐
# 60
# 13pro再战一年
# A15香啊
# 等一手龟兔赛跑
# 安迪比尔定律
# 省流 13香  A16=A15+ （doge
# 14plus估计是当年8plus的游戏地位了
# 牙膏
# 如何科学管理库存
# 明年就有typec了
# 连牙膏都没挤
# 等A18吧
# 高情商
# A15+++++++++++++++++++++++++++++++++++++
# 甚至还低了一帧
# a16还低了……
# 那么iphone 14就是过去五年iphone的总结了
# Intel是吧
# 十三不香咯
# 没卷了下代性能提升估计更小
# x狂喜
# A14GPU提升8%；A16直接提升0%
# 没对手就没必要提了
# 意思就是，超频版A15？
# 仅5   6分钟而已，，，
# 懂了，14pro的钱买13pm
# 没想到连苹果都开始挤牙膏了。。。
# @微机分
# 苹果便宜
# 难不成A16和M3芯片的性能一样？
# 没了散了吧明年被骁龙吊打了
# GenshinBench
# 为什么不是原神自身优化的问题呢
# 8100乱杀8GEN1
# 讲个笑话，我一个十一代i5配核显偶尔掉一点帧
# A15X（dog
# 懂了，等8gen2，让兄弟们先买ip14
# 明年的今年再回来看看这条视频
# 13香啊
# 笑死
# 买苹果不买pro系列及以上，不如不买
# 烧屏那个也太搞笑了吧
# 电池变小你叫进步？
# 8+比起8都不是一个物种了
# X65基带诚不欺我
# 懂了，是残血的A16，下年15就上满血的A16
# 其实就是N3难产导致的
# 865和870的区别，就是换了个制程工艺
# 8848
# 安卓中等还没苹果低等分辨率高  笑了
# 肯定是mhy干的
# A15.114514
# 还是13香，pro都没那么香

# %%
type(content_list)
# Out:
# list

# %%
resulttext = []
text = []
with open("A:/shixi/danmuiphone.txt", 'r', encoding='utf-8') as f:
    lines = f.readlines()
    for line in lines:
        line = line.strip('\n')
        seq_wards = jieba.lcut(line)
        text.append(line)
        resulttext.append('\t'.join(seq_wards))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\hrq\AppData\Local\Temp\jieba.cache
# Loading model cost 0.737 seconds.
# Prefix dict has been built successfully.

# %%
resulttext[:2]
# Out:
# ['负\t提升\t哈哈哈哈\t哈哈哈', '红魔\t是\t游戏\t手机\t啊\t大哥\t们\t，\t不是\t一条\t赛道\t的']

# %%
text[7]
# Out:
# '下次一定'

# %%
#哈工大停用词
stopwords = []
with open("A:/shixi/hagongda.txt",'r', encoding='utf-8') as f2:
    for i in f2:
        i = i.rstrip('\n')
        stopwords.append(i)
        
resulttext_ = []         
for word in resulttext:
    words = word.split('\t')
    #words = [s for s in words if len(s) > 1]
    word = [i for i in words if i not in stopwords]
    if len(word) >0:
        resulttext_.append(word)

# %%
resulttext_[:5]
# Out:
# [['负', '提升'],
#  ['红魔', '游戏', '手机', '大哥', '不是', '一条', '赛道'],
#  ['为啥', '麒麟', '9000', '没用', '散热', '背', '夹', '跑'],
#  ['夭寿', '苹果', '做', '散热'],
#  ['导游', '屏幕', '主板', '之间', '块', '铁板']]

# %%
result_final = []
for s in resulttext_:
    result_final.append('\t'.join(s))
#result_final[:5]

# %%
#通过测试发现使用jieba分词效果更好
s = SnowNLP(result_final[7])
s.sentiments

#s = SnowNLP(text[7])
#s.sentiments
# Out:
# 0.5689851767388825

# %%
#计算得分，添加score列表
score = []
tag = []
ls_pos = []
ls_neg = []
for sent in result_final:
    s = SnowNLP(sent).sentiments
    score.append(s)
    if s>0.5:
        tag.append(1)
        ls_pos.append(sent)
    else:
        tag.append(0)
        ls_neg.append(sent)

# %%
score2 = []
for sent in text:
    s = SnowNLP(sent).sentiments
    score2.append(round(s,2))
score2[:5]
# Out:
# [0.96, 0.98, 0.08, 0.55, 0.03]

# %%
#result_final[:10]
# Out:
# ['负\t提升',
#  '红魔\t游戏\t手机\t大哥\t不是\t一条\t赛道',
#  '为啥\t麒麟\t9000\t没用\t散热\t背\t夹\t跑',
#  '夭寿\t苹果\t做\t散热',
#  '导游\t屏幕\t主板\t之间\t块\t铁板',
#  '下次\t一定',
#  '说\t13\t香\t人',
#  '下次\t一定',
#  '寄\tPU',
#  '再\t不\t改\t后面\t可能\t会\t更\t大功率\t芯片\t没法用']

# %%
#score[:10]
# Out:
# [0.37973102383409907,
#  0.8879111932633647,
#  0.06707537647011586,
#  0.8399725296724299,
#  0.03270929849229398,
#  0.5689851767388825,
#  0.4421193908000549,
#  0.5689851767388825,
#  0.21058165908252657,
#  0.03866720569928106]

# %%
sum(tag)
# Out:
# 1953

# %%
#统计积极消极的个数
count_pos = sum(tag)
count_neg = len(tag)-sum(tag)
count_neg
# Out:
# 1557

# %%
#打包成数据框
emotion = pd.DataFrame()
emotion['comment'] = result_final
emotion['score'] = score
emotion['tag'] = tag
#emotion_pos = emotion[emotion['tag']==1]
#emotion_neg = emotion[emotion['tag']==0]

# %%
#emotion.shape
emotion.head(10)
#emotion_pos.head(5)
# Out:
#                                 comment     score  tag
# 0                                 负\t提升  0.379731    0
# 1            红魔\t游戏\t手机\t大哥\t不是\t一条\t赛道  0.887911    1
# 2         为啥\t麒麟\t9000\t没用\t散热\t背\t夹\t跑  0.067075    0
# 3                         夭寿\t苹果\t做\t散热  0.839973    1
# 4                 导游\t屏幕\t主板\t之间\t块\t铁板  0.032709    0
# 5                                下次\t一定  0.568985    1
# 6                           说\t13\t香\t人  0.442119    0
# 7                                下次\t一定  0.568985    1
# 8                                 寄\tPU  0.210582    0
# 9   再\t不\t改\t后面\t可能\t会\t更\t大功率\t芯片\t没法用  0.038667    0
# 10                               下次\t一定  0.568985    1
# 11                        天玑\t8000\t没想到  0.360898    0
# 12             众所周知\t原神\t测试\t手机\t性能\t软件  0.991239    1
# 13                               库克\t涨停  0.566132    1
# 14                     iPhone14\t系列\t新机  0.673354    1
# 15                               下次\t一定  0.568985    1
# 16                       乔布斯\t库克\t搞\t飞机  0.139244    0
# 17                               三连\t后续  0.513849    1
# 18                  散热\t背\t夹\t测试\t发热\t高  0.799051    1
# 19                                   安卓  0.954560    1

# %%
#统计词频--计算权重
#jieba.analyse.extract_tags()提取关键字的原理是使用TF-IDF算法
import jieba.analyse as analyse
comment = " ".join(text) #将含有字符串的列表转化为空格为间隔的字符串
jieba.analyse.set_stop_words('A:/shixi/hagongda.txt')
top = jieba.analyse.extract_tags(comment, withWeight = True, topK = 20 )
# Out:
#          0         1
# 0       13  0.209382
# 1       散热  0.155081
# 2       14  0.152919
# 3       苹果  0.112683
# 4       原神  0.098809
# 5   14plus  0.096457
# 6       安卓  0.087046
# 7      A15  0.075283
# 8       牙膏  0.074260
# 9      挤牙膏  0.073279
# 10      红魔  0.071124
# 11   13pro  0.067049
# 12     A16  0.064697
# 13      高通  0.062251
# 14      手机  0.060728
# 15      情商  0.055633
# 16      15  0.052934
# 17    doge  0.049405
# 18      烧屏  0.048228
# 19      骁龙  0.045876

# %%
#import wordcloud
from wordcloud import WordCloud,STOPWORDS
stopwords = STOPWORDS.add('都')
w = WordCloud( width = 1000, height = 700,stopwords=stopwords,background_color = "white",font_path = "msyh.ttc" )
w.generate(''.join (result_final))
w.to_file("result_final.png")

# %%
# 词云

w1 = WordCloud( width = 1000, height = 700,stopwords=stopwords,background_color = "white",font_path = "msyh.ttc" )
w1.generate(''.join (ls_pos))
w1.to_file("pos.png")

# %%
w2 = WordCloud( width = 1000, height = 700,stopwords=stopwords,background_color = "white",font_path = "msyh.ttc" )
w2.generate(''.join (ls_neg))
w2.to_file("neg.png")

# %%
#文本特征抽取tfidf
vectorizer = TfidfVectorizer() #实例化一个转换器对象
wordmtx=vectorizer.fit_transform(result_final)
#print(vectorizer.vocabulary_)  #结果即每个词及其对应的编号
#print(wordmtx)#e.g:（0,9061） 0.19821… 其中0代表第一行文本，9061表示编号为9061的词， 0.19821…表示其权重值

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train, x_test, y_train, y_test = train_test_split(wordmtx, tag, test_size=0.3, random_state=11)

# %%
#逻辑回归 f1 准确率 召回率 精确率
logitmodel=LogisticRegression()#定义回归模型
logitmodel.fit(x_train,y_train)#训练模型
print(classification_report(y_test,logitmodel.predict(x_test))) #f1得分
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.70      0.75       492
#            1       0.76      0.86      0.80       542
#
#     accuracy                           0.78      1034
#    macro avg       0.78      0.78      0.78      1034
# weighted avg       0.78      0.78      0.78      1034

# %%
#from sklearn import datasets, svm, metrics
# KNN
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier()
knn_clf.fit(x_train,y_train)
print(classification_report(y_test,knn_clf.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.96      0.70       492
#            1       0.88      0.30      0.45       542
#
#     accuracy                           0.61      1034
#    macro avg       0.72      0.63      0.58      1034
# weighted avg       0.73      0.61      0.57      1034

# %%
# 朴素贝叶斯
from sklearn.naive_bayes import MultinomialNB
bayes = MultinomialNB()
bayes.fit(x_train,y_train)
print(classification_report(y_test,bayes.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.67      0.75       492
#            1       0.75      0.88      0.81       542
#
#     accuracy                           0.78      1034
#    macro avg       0.79      0.78      0.78      1034
# weighted avg       0.79      0.78      0.78      1034

# %%
## SVM 支持向量机
# 定义分类器，clf 意为 classifier，是分类器的传统命名
from sklearn import svm
clf = svm.SVC(kernel = 'linear')  # .SVC（）就是 SVM 的方程，参数 kernel 为线性核函数
# 训练分类器
clf.fit(x_train,y_train)  # 调用分类器的 fit 函数建立模型（即计算出划分超平面，且所有相关属性都保存在了分类器 cls 里）
print(classification_report(y_test,clf.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       276
#            1       0.92      0.88      0.90       269
#
#     accuracy                           0.90       545
#    macro avg       0.91      0.90      0.90       545
# weighted avg       0.91      0.90      0.90       545
